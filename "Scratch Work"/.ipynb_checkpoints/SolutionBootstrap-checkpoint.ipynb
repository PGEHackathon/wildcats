# %%
import pandas as pd
import numpy as np

df = pd.read_csv('HackathonData2024.csv')

df.head()
# Out:
#    Well ID  Avg Pump Difference      Area  Lateral Length Fluid System  \
# 0        1                -0.93    Acadia           10300     Campbell
# 1        2                -8.45    Acadia           10300     Campbell
# 2        3                 8.70    Arches           11000     Campbell
# 3        4                  NaN    Arches           11000     Campbell
# 4        5                19.93  Badlands            2300     Campbell
#
#        TVD Development Strategy  DELAYED  BOUND_CODE CODEV_POSITION  ...  \
# 0  10415.0                 Coke        1    11100000           Edge  ...
# 1  10415.0                 Coke        1    11100000           Edge  ...
# 2   8470.0         Orange Crush        0      101111         Middle  ...
# 3  10555.0                 Coke        1    11110000           Edge  ...
# 4   9295.0         Mountain Dew        1    10001101           Edge  ...
#
#   CODEV_3000_AVG_TVD_DIST  CODEV_3000_AVG_WELL_AGE  \
# 0                       4                      0.0
# 1                       4                      0.0
# 2                     682                      4.5
# 3                       4                      0.0
# 4                     277                      1.0
#
#    CODEV_3000_MEDIAN_WELL_AGE  CODEV_3000_WELL_COUNT  \
# 0                         0.0                      1
# 1                         0.0                      1
# 2                         0.0                     11
# 3                         0.0                      1
# 4                         1.0                      2
#
#    Pressure Gradient (psi/ft) new  Soak Time  Avg Open Pressure  \
# 0                        0.593758         34        3304.124833
# 1                        0.597059         67        3301.199254
# 2                        0.516873         34        2774.407080
# 3                        0.501287         30        2653.539415
# 4                        0.503327        336                NaN
#
#    SD Open Pressure  Avg Close Pressure  SD Close Pressure
# 0             261.7         2719.898438              472.4
# 1             255.9         2934.885325              747.4
# 2             184.8         1589.948673              596.9
# 3             206.7         1304.162878              551.5
# 4               NaN                 NaN                NaN
#
# [5 rows x 41 columns]

# %%
test_well_list = [4, 31, 42, 52, 71, 76, 96, 131, 137, 194, 220, 236, 265, 321, 345]

test_wells = []
test_wells.append(df[df['Well ID'] == 4])
test_wells.append(df[df['Well ID'] == 31])
test_wells.append(df[df['Well ID'] == 42])
test_wells.append(df[df['Well ID'] == 52])
test_wells.append(df[df['Well ID'] == 71])
test_wells.append(df[df['Well ID'] == 76])
test_wells.append(df[df['Well ID'] == 96])
test_wells.append(df[df['Well ID'] == 131])
test_wells.append(df[df['Well ID'] == 137])
test_wells.append(df[df['Well ID'] == 194])
test_wells.append(df[df['Well ID'] == 220])
test_wells.append(df[df['Well ID'] == 236])
test_wells.append(df[df['Well ID'] == 265])
test_wells.append(df[df['Well ID'] == 321])
test_wells.append(df[df['Well ID'] == 345])
test_wells

df = df.drop(df[df['Well ID'] == 4].index)
df = df.drop(df[df['Well ID'] == 31].index)
df = df.drop(df[df['Well ID'] == 42].index)
df = df.drop(df[df['Well ID'] == 52].index)
df = df.drop(df[df['Well ID'] == 71].index)
df = df.drop(df[df['Well ID'] == 76].index)
df = df.drop(df[df['Well ID'] == 96].index)
df = df.drop(df[df['Well ID'] == 131].index)
df = df.drop(df[df['Well ID'] == 137].index)
df = df.drop(df[df['Well ID'] == 194].index)
df = df.drop(df[df['Well ID'] == 220].index)
df = df.drop(df[df['Well ID'] == 236].index)
df = df.drop(df[df['Well ID'] == 265].index)
df = df.drop(df[df['Well ID'] == 321].index)
df = df.drop(df[df['Well ID'] == 345].index)
df
# Out:
#      Well ID  Avg Pump Difference           Area  Lateral Length Fluid System  \
# 0          1                -0.93         Acadia           10300     Campbell
# 1          2                -8.45         Acadia           10300     Campbell
# 2          3                 8.70         Arches           11000     Campbell
# 4          5                19.93       Badlands            2300     Campbell
# 5          6                -4.34       Big Bend           12300     Campbell
# ..       ...                  ...            ...             ...          ...
# 343      352                81.43     Everglades           13000          NaN
# 344      353                68.21  Mount Rainier            7700     Williams
# 345      354                29.18  Mount Rainier            7700          NaN
# 346      355                80.59     Everglades           12900          NaN
# 347      356                30.42  Mount Rainier            7700          NaN
#
#          TVD Development Strategy  DELAYED  BOUND_CODE CODEV_POSITION  ...  \
# 0    10415.0                 Coke        1    11100000           Edge  ...
# 1    10415.0                 Coke        1    11100000           Edge  ...
# 2     8470.0         Orange Crush        0      101111         Middle  ...
# 4     9295.0         Mountain Dew        1    10001101           Edge  ...
# 5    10355.0                 Coke        1    11110000           Edge  ...
# ..       ...                  ...      ...         ...            ...  ...
# 343   8270.0         Orange Crush        1    11001111           Edge  ...
# 344  10365.0                 Coke        1    11111000           Edge  ...
# 345  10300.0                 Coke        1    11111000           Edge  ...
# 346  10410.0                 Coke        0    11000000           Edge  ...
# 347  10355.0                 Coke        1    11111001           Edge  ...
#
#     CODEV_3000_AVG_TVD_DIST  CODEV_3000_AVG_WELL_AGE  \
# 0                         4                      0.0
# 1                         4                      0.0
# 2                       682                      4.5
# 4                       277                      1.0
# 5                      1410                     21.5
# ..                      ...                      ...
# 343                     238                     -7.8
# 344                      10                      0.0
# 345                      12                      0.0
# 346                      12                      0.0
# 347                      11                      0.0
#
#      CODEV_3000_MEDIAN_WELL_AGE  CODEV_3000_WELL_COUNT  \
# 0                           0.0                      1
# 1                           0.0                      1
# 2                           0.0                     11
# 4                           1.0                      2
# 5                          28.5                      4
# ..                          ...                    ...
# 343                         1.0                      5
# 344                         0.0                      1
# 345                         0.0                      1
# 346                         0.0                      1
# 347                         0.0                      1
#
#      Pressure Gradient (psi/ft) new  Soak Time  Avg Open Pressure  \
# 0                          0.593758         34        3304.124833
# 1                          0.597059         67        3301.199254
# 2                          0.516873         34        2774.407080
# 4                          0.503327        336                NaN
# 5                          0.565200         21        2963.567911
# ..                              ...        ...                ...
# 343                        0.477837        467        2667.717992
# 344                        0.512640        245        3056.211966
# 345                        0.530874        315        2969.985594
# 346                        0.478153        541        2761.233882
# 347                        0.530376        355        2966.579531
#
#      SD Open Pressure  Avg Close Pressure  SD Close Pressure
# 0               261.7         2719.898438              472.4
# 1               255.9         2934.885325              747.4
# 2               184.8         1589.948673              596.9
# 4                 NaN                 NaN                NaN
# 5               232.0         2063.408619              517.8
# ..                ...                 ...                ...
# 343             267.3         2357.296098              589.9
# 344             212.0         2032.922355              533.8
# 345             230.1         1821.549742              314.5
# 346            1035.5         2149.114144              779.2
# 347             158.1         1818.192820              360.6
#
# [333 rows x 41 columns]

# %%
def bootstrap_sample(dataframe):
    return dataframe.sample(n=len(dataframe), replace=True)

num_iterations = 100
bootstrap_samples = []

for _ in range(num_iterations):
    bootstrap_sample_df = bootstrap_sample(df)
    bootstrap_samples.append(bootstrap_sample_df)

# %%
import sklearn
from sklearn.datasets import make_regression
import pandas
from sklearn import linear_model
from sklearn import model_selection
from sklearn.metrics import accuracy_score

import os                                                 # to set current working directory 
import math                                               # basic calculations like square root
from sklearn.model_selection import train_test_split      # train and test split
from sklearn import tree                                  # tree program from scikit learn (package for machine learning)
from sklearn.metrics import mean_squared_error            # specific measures to check our models
import pandas as pd                                       # DataFrames for tabular data
import numpy as np                                        # arrays and matrix math
import matplotlib.pyplot as plt                           # general plotting
import seaborn as sns

import os                                                   # to set current working directory 
import math                                                 # basic calculations like square root
import pandas as pd                                         # DataFrames and plotting
import numpy as np                                          # arrays and matrix math
import matplotlib.pyplot as plt                             # plotting
import matplotlib.ticker as ticker                          # modify the plot axis labels
from sklearn.model_selection import train_test_split        # train and test split
from sklearn.pipeline import Pipeline                       # machine learning modeling pipeline
from sklearn.model_selection import GridSearchCV            # model hyperparameter grid search
from sklearn.model_selection import KFold                   # k-fold cross validation
from sklearn.preprocessing import StandardScaler            # feature standardization
np.random.seed(seed=73038)                                  # set the random number seed
import warnings
warnings.filterwarnings('ignore')  
import sklearn.tree
from sklearn.feature_selection import RFECV

# %%
solution_df = pd.read_csv('solution.csv')

decision_tree_reg = tree.DecisionTreeRegressor(max_leaf_nodes = 10)

predictions = []

for i in range(num_iterations):
    X = bootstrap_samples[i][['TVD', 'SD Open Pressure', 'CODEV_OUT_ZONE_MIN_HYPOT', 'Pressure Gradient (psi/ft) new', 'Soak Time', 'Avg Open Pressure', 'Avg Close Pressure']]
    y = bootstrap_samples[i]['Avg Pump Difference']
    decision_tree_reg.fit(X, y)
    print(decision_tree_reg.score(X, y))
    arr = []
    for j in range(15):
        pred = decision_tree_reg.predict(test_wells[j][['TVD', 'SD Open Pressure', 'CODEV_OUT_ZONE_MIN_HYPOT', 'Pressure Gradient (psi/ft) new', 'Soak Time', 'Avg Open Pressure', 'Avg Close Pressure']])
        arr.append(pred[0])
    predictions.append(arr)
# Out:
# 0.6236488857465952
# 0.6490894126114461
# 0.5633175159308814
# 0.5651470666744975
# 0.5951111180414075
# 0.6347271282178856
# 0.6051711872748653
# 0.5037248727158845
# 0.5817358906437943
# 0.6285023493522512
# 0.4498546116462182
# 0.5878310800786886
# 0.5245646723869093
# 0.6354102020321761
# 0.5564911673111481
# 0.49893667132561126
# 0.5220517806873013
# 0.577570582140617
# 0.4875405141939332
# 0.6095066531773583
# 0.6292057847681393
# 0.5547053626846841
# 0.6707339467735423
# 0.6219253743026456
# 0.649370129871186
# 0.5714718995006574
# 0.48285035105256724
# 0.5792273173103413
# 0.5983434829928969
# 0.5921554927995785
# 0.5683278340330804
# 0.532012553352629
# 0.5526845528522047
# 0.4699638037662517
# 0.4217409986908611
# 0.6233320334146149
# 0.5945281070448927
# 0.48914764044729164
# 0.6146343625617485
# 0.5286025530408576
# 0.6113619943074771
# 0.5562538432182176
# 0.515756839181081
# 0.62572785031657
# 0.4453247220305897
# 0.610973879606078
# 0.5638025408331031
# 0.5262588486132926
# 0.634216368872978
# 0.45346038597388494
# 0.5960379229619996
# 0.6106762329944706
# 0.5226178576275692
# 0.6200814443393454
# 0.5347087608960939
# 0.5857466211540276
# 0.524753306177604
# 0.6146447010851435
# 0.6172126420677052
# 0.6319561213407704
# 0.6052796428048961
# 0.6073010201849733
# 0.4755077973083929
# 0.5187616322166793
# 0.5702296057326197
# 0.5115508507201397
# 0.5168710517263748
# 0.6257929656865107
# 0.5824739882122809
# 0.6102719273336397
# 0.5432441687960935
# 0.6917237658254243
# 0.6081056321411564
# 0.669333200038033
# 0.610486274900258
# 0.585616180902619
# 0.5690353538629451
# 0.565278707575025
# 0.6200797694749831
# 0.6278724680548863
# 0.5913521180728731
# 0.5909534184997626
# 0.6016304537300341
# 0.4985793168737004
# 0.626038726387425
# 0.5351007028366713
# 0.5543499280118351
# 0.5709611265671053
# 0.5109993650529465
# 0.27857046467571667
# 0.6071939888643404
# 0.5596759061094861
# 0.48832480298285585
# 0.6488715070225388
# 0.6046213139095817
# 0.5903447452364337
# 0.6239375681368559
# 0.5793189386617771
# 0.5259773084485604
# 0.6112288825432719

# %%
len(predictions)
# Out:
# 100

# %%
for i in range(1, 101):
    solution_df['R' + str(i) + ', GPM'] = predictions[i - 1]

# %%
solution_df
# Out:
#     Well_ID  Est Pump Difference, GPM    R1, GPM    R2, GPM    R3, GPM  \
# 0         4                 28.227034   5.792941  40.921456   2.440000
# 1        31                 29.930811  19.753143   0.544286  17.015556
# 2        42                  5.793646   2.443692  -0.602222  11.407671
# 3        52                  5.215419   2.443692  10.343500  11.407671
# 4        71                 27.614860  19.753143  40.921456   2.440000
# 5        76                  6.990425   2.443692  10.343500  11.407671
# 6        96                 21.243669  28.808846  40.921456   2.440000
# 7       131                  9.330744   2.443692  10.343500  11.407671
# 8       137                  4.832812   2.443692  -0.602222   2.440000
# 9       194                 46.184823  73.102609  40.921456  44.481806
# 10      220                  5.646472   2.443692  10.343500  11.407671
# 11      236                 25.036960  19.753143  40.921456  17.015556
# 12      265                 49.288206  41.794259  40.921456  44.481806
# 13      321                  5.368379   2.443692  10.343500  11.407671
# 14      345                  6.702823   2.443692  16.833607  11.407671
#
#       R4, GPM    R5, GPM    R6, GPM    R7, GPM    R8, GPM  ...   R91, GPM  \
# 0   34.506471  29.048571  32.782830  32.829672  29.500000  ...  38.075495
# 1   15.966047  15.831724   6.936250  14.368788  29.500000  ...  38.075495
# 2    6.050505   5.086729   4.420928   6.372381   2.705814  ...   2.508286
# 3    6.050505   5.086729   4.420928   6.372381   2.705814  ...   2.508286
# 4   34.506471  29.048571  32.782830  21.777500  29.500000  ...  25.071250
# 5    6.050505   5.086729   4.420928   6.372381   2.705814  ...   2.508286
# 6   60.350000  15.831724  32.782830  14.368788  11.138507  ...  25.071250
# 7    6.050505   5.086729   4.420928   6.372381   2.705814  ...   2.508286
# 8    6.050505   5.086729   4.420928   6.372381   2.705814  ...   2.508286
# 9   67.300000  97.380000  80.856667  32.829672  45.994028  ...  82.343333
# 10   6.050505   5.086729   4.420928   6.372381   2.705814  ...   2.508286
# 11  15.966047  47.767778  32.782830  32.829672  26.062889  ...  25.071250
# 12  31.734400  39.490606  40.452927  50.692245  45.994028  ...  38.075495
# 13   6.050505   5.086729   4.420928   6.372381   2.705814  ...   2.508286
# 14   6.050505   5.086729  16.246452   6.372381   2.705814  ...   2.508286
#
#      R92, GPM   R93, GPM   R94, GPM   R95, GPM   R96, GPM   R97, GPM  \
# 0   31.776341  30.546277  46.321667  31.121000  37.281429  18.427308
# 1   61.046923  30.546277  18.674375  -5.570000  37.281429  28.386410
# 2    2.493210  -0.003696   4.251458   5.175140  17.218583   2.488125
# 3    2.493210  -0.003696   4.251458   5.175140  17.218583   2.488125
# 4   13.276935  30.546277  46.321667  31.121000  37.281429  18.427308
# 5    2.493210  15.424091   4.251458   5.175140  17.218583   2.488125
# 6   21.014062  30.546277   2.793125  11.624348   5.945581   2.179545
# 7    2.493210  15.424091   4.251458   5.175140  17.218583   2.488125
# 8    2.493210  -0.003696   4.251458   5.175140  -0.248750   2.488125
# 9   48.832632  47.057143  67.197368  48.801186  82.040000  71.083478
# 10   2.493210  -0.003696   4.251458   5.175140  17.218583   2.488125
# 11  13.276935  47.057143  18.674375  31.121000  17.218583  28.386410
# 12  48.832632  30.546277  33.159762  48.801186  43.611667  35.658409
# 13   2.493210  -0.003696   4.251458   5.175140  17.218583   2.488125
# 14   2.493210  -0.003696  18.012727   5.175140  17.218583   2.488125
#
#      R98, GPM   R99, GPM  R100, GPM
# 0   31.245902  21.628941  54.170179
# 1   13.273947  21.628941  54.170179
# 2    2.570722   1.305823   2.203187
# 3    2.570722   1.305823   2.203187
# 4   31.245902  21.628941  24.946667
# 5    2.570722   1.305823   2.203187
# 6   13.273947  21.628941  13.190435
# 7    2.570722   1.305823   2.203187
# 8    2.570722   1.305823   2.203187
# 9   49.589344  74.060000  71.981667
# 10   2.570722   1.305823   2.203187
# 11  13.273947  21.628941  20.210426
# 12  49.589344  55.178000  54.170179
# 13   2.570722   1.305823   2.203187
# 14   2.570722   1.305823   2.203187
#
# [15 rows x 102 columns]

# %%
means = []
for i in range(0, 15):
    arr2 = solution_df.iloc[[i]].to_numpy()
    arr2 = np.delete(arr2,[0])
    arr2 = np.delete(arr2,[0])
    means.append(sum(arr2) / len(arr2))
    
means
# Out:
# [29.98071542230447,
#  29.371386908108374,
#  4.587970440317539,
#  4.1910893524162764,
#  28.19098126598301,
#  5.873913151087958,
#  22.42796016700944,
#  6.32086087187575,
#  3.160911274415848,
#  52.83591350027486,
#  4.48685612926734,
#  25.741814141656874,
#  40.92359593060636,
#  4.364563880207657,
#  6.396082375725083]

# %%
solution_df['Est Pump Difference, GPM'] = means
solution_df
# Out:
#     Well_ID  Est Pump Difference, GPM    R1, GPM    R2, GPM    R3, GPM  \
# 0         4                 29.980715   5.792941  40.921456   2.440000
# 1        31                 29.371387  19.753143   0.544286  17.015556
# 2        42                  4.587970   2.443692  -0.602222  11.407671
# 3        52                  4.191089   2.443692  10.343500  11.407671
# 4        71                 28.190981  19.753143  40.921456   2.440000
# 5        76                  5.873913   2.443692  10.343500  11.407671
# 6        96                 22.427960  28.808846  40.921456   2.440000
# 7       131                  6.320861   2.443692  10.343500  11.407671
# 8       137                  3.160911   2.443692  -0.602222   2.440000
# 9       194                 52.835914  73.102609  40.921456  44.481806
# 10      220                  4.486856   2.443692  10.343500  11.407671
# 11      236                 25.741814  19.753143  40.921456  17.015556
# 12      265                 40.923596  41.794259  40.921456  44.481806
# 13      321                  4.364564   2.443692  10.343500  11.407671
# 14      345                  6.396082   2.443692  16.833607  11.407671
#
#       R4, GPM    R5, GPM    R6, GPM    R7, GPM    R8, GPM  ...   R91, GPM  \
# 0   34.506471  29.048571  32.782830  32.829672  29.500000  ...  38.075495
# 1   15.966047  15.831724   6.936250  14.368788  29.500000  ...  38.075495
# 2    6.050505   5.086729   4.420928   6.372381   2.705814  ...   2.508286
# 3    6.050505   5.086729   4.420928   6.372381   2.705814  ...   2.508286
# 4   34.506471  29.048571  32.782830  21.777500  29.500000  ...  25.071250
# 5    6.050505   5.086729   4.420928   6.372381   2.705814  ...   2.508286
# 6   60.350000  15.831724  32.782830  14.368788  11.138507  ...  25.071250
# 7    6.050505   5.086729   4.420928   6.372381   2.705814  ...   2.508286
# 8    6.050505   5.086729   4.420928   6.372381   2.705814  ...   2.508286
# 9   67.300000  97.380000  80.856667  32.829672  45.994028  ...  82.343333
# 10   6.050505   5.086729   4.420928   6.372381   2.705814  ...   2.508286
# 11  15.966047  47.767778  32.782830  32.829672  26.062889  ...  25.071250
# 12  31.734400  39.490606  40.452927  50.692245  45.994028  ...  38.075495
# 13   6.050505   5.086729   4.420928   6.372381   2.705814  ...   2.508286
# 14   6.050505   5.086729  16.246452   6.372381   2.705814  ...   2.508286
#
#      R92, GPM   R93, GPM   R94, GPM   R95, GPM   R96, GPM   R97, GPM  \
# 0   31.776341  30.546277  46.321667  31.121000  37.281429  18.427308
# 1   61.046923  30.546277  18.674375  -5.570000  37.281429  28.386410
# 2    2.493210  -0.003696   4.251458   5.175140  17.218583   2.488125
# 3    2.493210  -0.003696   4.251458   5.175140  17.218583   2.488125
# 4   13.276935  30.546277  46.321667  31.121000  37.281429  18.427308
# 5    2.493210  15.424091   4.251458   5.175140  17.218583   2.488125
# 6   21.014062  30.546277   2.793125  11.624348   5.945581   2.179545
# 7    2.493210  15.424091   4.251458   5.175140  17.218583   2.488125
# 8    2.493210  -0.003696   4.251458   5.175140  -0.248750   2.488125
# 9   48.832632  47.057143  67.197368  48.801186  82.040000  71.083478
# 10   2.493210  -0.003696   4.251458   5.175140  17.218583   2.488125
# 11  13.276935  47.057143  18.674375  31.121000  17.218583  28.386410
# 12  48.832632  30.546277  33.159762  48.801186  43.611667  35.658409
# 13   2.493210  -0.003696   4.251458   5.175140  17.218583   2.488125
# 14   2.493210  -0.003696  18.012727   5.175140  17.218583   2.488125
#
#      R98, GPM   R99, GPM  R100, GPM
# 0   31.245902  21.628941  54.170179
# 1   13.273947  21.628941  54.170179
# 2    2.570722   1.305823   2.203187
# 3    2.570722   1.305823   2.203187
# 4   31.245902  21.628941  24.946667
# 5    2.570722   1.305823   2.203187
# 6   13.273947  21.628941  13.190435
# 7    2.570722   1.305823   2.203187
# 8    2.570722   1.305823   2.203187
# 9   49.589344  74.060000  71.981667
# 10   2.570722   1.305823   2.203187
# 11  13.273947  21.628941  20.210426
# 12  49.589344  55.178000  54.170179
# 13   2.570722   1.305823   2.203187
# 14   2.570722   1.305823   2.203187
#
# [15 rows x 102 columns]

# %%
solution_df.to_csv('solution.csv', index=False, encoding='utf-8')
