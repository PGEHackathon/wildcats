# %%
import pandas
from sklearn import linear_model
from sklearn import model_selection
from sklearn.metrics import accuracy_score

import os                                                 # to set current working directory 
import math                                               # basic calculations like square root
from sklearn.model_selection import train_test_split      # train and test split
from sklearn import tree                                  # tree program from scikit learn (package for machine learning)
from sklearn.metrics import mean_squared_error            # specific measures to check our models
import pandas as pd                                       # DataFrames for tabular data
import numpy as np                                        # arrays and matrix math
import matplotlib.pyplot as plt                           # general plotting
import seaborn as sns

import os                                                   # to set current working directory 
import math                                                 # basic calculations like square root
import pandas as pd                                         # DataFrames and plotting
import numpy as np                                          # arrays and matrix math
import matplotlib.pyplot as plt                             # plotting
import matplotlib.ticker as ticker                          # modify the plot axis labels
from sklearn.model_selection import train_test_split        # train and test split
from sklearn.pipeline import Pipeline                       # machine learning modeling pipeline
from sklearn.model_selection import GridSearchCV            # model hyperparameter grid search
from sklearn.model_selection import KFold                   # k-fold cross validation
from sklearn.preprocessing import StandardScaler            # feature standardization
np.random.seed(seed=73038)                                  # set the random number seed
import warnings
warnings.filterwarnings('ignore')

# %%
df = pandas.read_csv("ImputedValues.csv")

# %%
X = df[['TVD', 'CODEV_OUT_ZONE_MIN_HYPOT', 'Pressure Gradient (psi/ft) new',
       'Avg Open Pressure', 'Avg Close Pressure']]

y = df['Avg Pump Difference']

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.2, random_state=832)

# %%
linear = linear_model.LinearRegression()
linear.fit(X_train, y_train)

pred = linear.predict(X_test) # Not sure what to do with this yet

print('Training Accuracy %:', linear.score(X_train, y_train) * 100)
print('Testing Accuracy %:', linear.score(X_test, y_test) * 100)
# Out:
# Training Accuracy %: 39.12138897723535
# Testing Accuracy %: 35.290350975325666

# %%
decision_tree_reg = tree.DecisionTreeRegressor(max_leaf_nodes = 10) # make the model object and set the hyperparameters
decision_tree_reg.fit(X_train, y_train)

pred = decision_tree_reg.predict(X_test)

print(decision_tree_reg.score(X_train, y_train))
print(decision_tree_reg.score(X_test, y_test))

for num in range(2, 100):
    decision_tree_reg = tree.DecisionTreeRegressor(max_leaf_nodes = num) # make the model object and set the hyperparameters
    decision_tree_reg.fit(X_train, y_train)

    pred = decision_tree_reg.predict(X_test)
    
    print(num)
    print(decision_tree_reg.score(X_train, y_train))
    print(decision_tree_reg.score(X_test, y_test))
    print()
# Out:
# 0.5918516367041611
# 0.5551019739035797
# 2
# 0.25667113163125765
# 0.12550228919227013
#
# 3
# 0.36001580840925007
# 0.19268251665264202
#
# 4
# 0.40661423284919274
# 0.2049493129208686
#
# 5
# 0.4519193118745939
# 0.35710489207842633
#
# 6
# 0.4898412735693126
# 0.37217812831860964
#
# 7
# 0.518856728141716
# 0.4482566195709916
#
# 8
# 0.5477566236121028
# 0.49764833560360056
#
# 9
# 0.573752497415446
# 0.5615063722248639
#
# 10
# 0.5918516367041611
# 0.5551019739035796
#
# 11
# 0.6094829501847134
# 0.5425467747033568
#
# 12
# 0.6270241100317389
# 0.543999977165597
#
# 13
# 0.6416210378363343
# 0.415258671186463
#
# 14
# 0.6570967506465588
# 0.4041559319219954
#
# 15
# 0.6703909780285946
# 0.5162778174130989
#
# 16
# 0.6833286463889586
# 0.4890063078881963
#
# 17
# 0.6961230723214807
# 0.38023905609620334
#
# 18
# 0.7066916999686277
# 0.5100704366207638
#
# 19
# 0.7172462237673006
# 0.4063760516016799
#
# 20
# 0.7265790986505807
# 0.4195099026397524
#
# 21
# 0.735893136522778
# 0.4205016871289944
#
# 22
# 0.7434888203704372
# 0.41153851538283925
#
# 23
# 0.7509702504992848
# 0.5238708529052147
#
# 24
# 0.7576745271231021
# 0.5095925243255524
#
# 25
# 0.7643413100347147
# 0.5095925243255524
#
# 26
# 0.7709672679267183
# 0.41234227595400563
#
# 27
# 0.7776718473523623
# 0.3943025943883527
#
# 28
# 0.7842844176593237
# 0.38375074648629115
#
# 29
# 0.7906572988060476
# 0.33996928696541007
#
# 30
# 0.7970052027868542
# 0.43353966490316664
#
# 31
# 0.8023501477349724
# 0.43144895223796853
#
# 32
# 0.8070088217859808
# 0.43144895223796853
#
# 33
# 0.8114862849309162
# 0.4263201160177371
#
# 34
# 0.8155266781135724
# 0.42737993952437847
#
# 35
# 0.8223077670904877
# 0.43635705553242154
#
# 36
# 0.826282009211344
# 0.3212672413280202
#
# 37
# 0.8322902386421878
# 0.3148098776616469
#
# 38
# 0.8395481463404169
# 0.3261144728633092
#
# 39
# 0.8447717250339273
# 0.28029372431673116
#
# 40
# 0.8507691416090094
# 0.2772078791462427
#
# 41
# 0.8547005722229309
# 0.3183296466293153
#
# 42
# 0.858598564882874
# 0.319801237067015
#
# 43
# 0.8623731308469446
# 0.2709083280882777
#
# 44
# 0.8659912732069843
# 0.2569929998916497
#
# 45
# 0.8695915747232288
# 0.38450671836055494
#
# 46
# 0.8731916374954997
# 0.25073007101616385
#
# 47
# 0.8766807585091609
# 0.40333677102141985
#
# 48
# 0.8800098995459468
# 0.35835681130292896
#
# 49
# 0.8831458304810232
# 0.36537034952588987
#
# 50
# 0.8862276107267314
# 0.2342773844318191
#
# 51
# 0.8892569020585127
# 0.40431883365057686
#
# 52
# 0.8933938548756293
# 0.27872229942820015
#
# 53
# 0.8963246275955944
# 0.34110973431240665
#
# 54
# 0.8991170707471481
# 0.3641770837686309
#
# 55
# 0.9045549206659211
# 0.32799752615844624
#
# 56
# 0.9077333158455033
# 0.227732539661736
#
# 57
# 0.9104306383877142
# 0.3374482688581858
#
# 58
# 0.9129735645994257
# 0.3410836252092443
#
# 59
# 0.9154779952582219
# 0.31678245597008725
#
# 60
# 0.9179532278323531
# 0.3535411651083705
#
# 61
# 0.9204133126489223
# 0.262727797275215
#
# 62
# 0.9227509691481137
# 0.3659301142305129
#
# 63
# 0.9278387536928178
# 0.2536395243011025
#
# 64
# 0.9319118220748317
# 0.25952780008407983
#
# 65
# 0.9341594499654766
# 0.24155800614846834
#
# 66
# 0.936374542266517
# 0.3351325382989644
#
# 67
# 0.9385595902748457
# 0.3721199741074027
#
# 68
# 0.9405944924439877
# 0.39801142861759764
#
# 69
# 0.9426224345790297
# 0.400009985747944
#
# 70
# 0.9446202167477451
# 0.3364734800920771
#
# 71
# 0.9464178350347451
# 0.4024049513585699
#
# 72
# 0.9479147661797973
# 0.247709262443629
#
# 73
# 0.949360567749351
# 0.37641231311874424
#
# 74
# 0.9509688564871261
# 0.35946555158063287
#
# 75
# 0.9523112376784231
# 0.3565861027764472
#
# 76
# 0.9536034434256491
# 0.35341200865462197
#
# 77
# 0.9548855996150108
# 0.2571584439067798
#
# 78
# 0.9561468284168788
# 0.2763248771317983
#
# 79
# 0.9573645318722637
# 0.4302271310352237
#
# 80
# 0.95852046530713
# 0.38442106929854325
#
# 81
# 0.9596342834353654
# 0.3652132484864552
#
# 82
# 0.9607421762085735
# 0.2554975192900053
#
# 83
# 0.9618498150683927
# 0.2532056728167823
#
# 84
# 0.9629331231119637
# 0.4137487247905539
#
# 85
# 0.9638864543619613
# 0.24105081050639732
#
# 86
# 0.9649160521119587
# 0.2783980934495236
#
# 87
# 0.9658589499910286
# 0.2844975984524485
#
# 88
# 0.9667405980168908
# 0.28334748792021014
#
# 89
# 0.967599298151127
# 0.3969086142595055
#
# 90
# 0.9687778996966375
# 0.2838037481706148
#
# 91
# 0.9696116332844205
# 0.2786003355133895
#
# 92
# 0.9704421189229826
# 0.2538906194567163
#
# 93
# 0.9712722258065025
# 0.2718604133923277
#
# 94
# 0.9720570065795173
# 0.232556881577912
#
# 95
# 0.9728015444123617
# 0.38114331892157405
#
# 96
# 0.9735171731049749
# 0.35272483974406454
#
# 97
# 0.9742277227976809
# 0.3560240443899523
#
# 98
# 0.9749092554559468
# 0.2626186896860384
#
# 99
# 0.9755598407794291
# 0.26015974023505883

# %%
from sklearn.ensemble import RandomForestRegressor        

# fnodes = 20                                            # hyperparameters
# fnodes_min = 2; fnodes_max=100; fnnodes = 40              

# #max_depth = 40                                            
# n_estimators = 20
# max_features = 5

# forest_model = RandomForestRegressor(max_leaf_nodes=fnodes,random_state=73073,n_estimators=n_estimators, max_features=max_features)
# forest_model.fit(X_train,y_train) # train the model with training data 

# print(forest_model.score(X_train, y_train))
# print(forest_model.score(X_test, y_test))

rf_df = pd.DataFrame([], columns=[])

for nodes in range(15, 70):
    for n_estimator in range(20, 80):
        for max_feature in range (1, 9):
            forest_model = RandomForestRegressor(max_leaf_nodes=nodes,random_state=73073,n_estimators=n_estimator, max_features=max_feature)
            forest_model.fit(X_train,y_train) # train the model with training data 
            
            print('nodes', nodes)
            print('n_estimators', n_estimator)
            print('max_features', max_feature)
            print('Training Accuracy %:', forest_model.score(X_train, y_train))
            print('Testing Accuracy %:', forest_model.score(X_test, y_test))
# Out:
# nodes 15
# n_estimators 20
# max_features 1
# Training Accuracy %: 0.6045850812219895
# Testing Accuracy %: 0.3916096092890575
# nodes 15
# n_estimators 20
# max_features 2
# Training Accuracy %: 0.6743807945387762
# Testing Accuracy %: 0.3479288712464368
# nodes 15
# n_estimators 20
# max_features 3
# Training Accuracy %: 0.6795491182139661
# Testing Accuracy %: 0.3668735359924793
# nodes 15
# n_estimators 20
# max_features 4
# Training Accuracy %: 0.6937433720806869
# Testing Accuracy %: 0.4139787496651588
# nodes 15
# n_estimators 20
# max_features 5
# Training Accuracy %: 0.7228913471332193
# Testing Accuracy %: 0.45056855236891313
# nodes 15
# n_estimators 20
# max_features 6
# Training Accuracy %: 0.7062969620180234
# Testing Accuracy %: 0.43560380347189276
# nodes 15
# n_estimators 20
# max_features 7
# Training Accuracy %: 0.7113854854983905
# Testing Accuracy %: 0.45036498222727495
# nodes 15
# n_estimators 20
# max_features 8
# Training Accuracy %: 0.7138978220871417
# Testing Accuracy %: 0.41711323695464475
# nodes 15
# n_estimators 21
# max_features 1
# Training Accuracy %: 0.5990002489490849
# Testing Accuracy %: 0.3748862059748985
# nodes 15
# n_estimators 21
# max_features 2
# Training Accuracy %: 0.6735719103375393
# Testing Accuracy %: 0.3519857699688751
# nodes 15
# n_estimators 21
# max_features 3
# Training Accuracy %: 0.6820131632289496
# Testing Accuracy %: 0.370513125492246
# nodes 15
# n_estimators 21
# max_features 4
# Training Accuracy %: 0.6971914133047279
# Testing Accuracy %: 0.4152348944014691
# nodes 15
# n_estimators 21
# max_features 5
# Training Accuracy %: 0.7217092996415848
# Testing Accuracy %: 0.4577810483659822
# nodes 15
# n_estimators 21
# max_features 6
# Training Accuracy %: 0.7102187918323595
# Testing Accuracy %: 0.44021870718871214
# nodes 15
# n_estimators 21
# max_features 7
# Training Accuracy %: 0.7125380756353712
# Testing Accuracy %: 0.4502154647639327
# nodes 15
# n_estimators 21
# max_features 8
# Training Accuracy %: 0.7171649344423816
# Testing Accuracy %: 0.4163300767883513
# nodes 15
# n_estimators 22
# max_features 1
# Training Accuracy %: 0.6008715100166927
# Testing Accuracy %: 0.3741050407717479
# nodes 15
# n_estimators 22
# max_features 2
# Training Accuracy %: 0.6720431900946543
# Testing Accuracy %: 0.3601701492787195
# nodes 15
# n_estimators 22
# max_features 3
# Training Accuracy %: 0.6828489253357324
# Testing Accuracy %: 0.3669539062863628
# nodes 15
# n_estimators 22
# max_features 4
# Training Accuracy %: 0.698939799762714
# Testing Accuracy %: 0.41015137653681155
# nodes 15
# n_estimators 22
# max_features 5
# Training Accuracy %: 0.7185041005177202
# Testing Accuracy %: 0.45263609801276605
# nodes 15
# n_estimators 22
# max_features 6
# Training Accuracy %: 0.7085928828763735
# Testing Accuracy %: 0.43839926023483344
# nodes 15
# n_estimators 22
# max_features 7
# Training Accuracy %: 0.7137593858943372
# Testing Accuracy %: 0.4514332231474105
# nodes 15
# n_estimators 22
# max_features 8
# Training Accuracy %: 0.7177933270918839
# Testing Accuracy %: 0.4186736530101569
# nodes 15
# n_estimators 23
# max_features 1
# Training Accuracy %: 0.600793859907809
# Testing Accuracy %: 0.3709114858228554
# nodes 15
# n_estimators 23
# max_features 2
# Training Accuracy %: 0.6731709548429272
# Testing Accuracy %: 0.3541967173608904
# nodes 15
# n_estimators 23
# max_features 3
# Training Accuracy %: 0.6837096457440333
# Testing Accuracy %: 0.35934603066367843
# nodes 15
# n_estimators 23
# max_features 4
# Training Accuracy %: 0.6981509057081108
# Testing Accuracy %: 0.40663433138873695
# nodes 15
# n_estimators 23
# max_features 5
# Training Accuracy %: 0.7174434965734968
# Testing Accuracy %: 0.4609948684609423
# nodes 15
# n_estimators 23
# max_features 6
# Training Accuracy %: 0.707991058248478
# Testing Accuracy %: 0.445084788900601
# nodes 15
# n_estimators 23
# max_features 7
# Training Accuracy %: 0.7144149445703138
# Testing Accuracy %: 0.4565834203366601
# nodes 15
# n_estimators 23
# max_features 8
# Training Accuracy %: 0.7205078963201301
# Testing Accuracy %: 0.425532538098366
# nodes 15
# n_estimators 24
# max_features 1
# Training Accuracy %: 0.6040660446115035
# Testing Accuracy %: 0.3788895468021909
# nodes 15
# n_estimators 24
# max_features 2
# Training Accuracy %: 0.6714259110752638
# Testing Accuracy %: 0.3617938451082866
# nodes 15
# n_estimators 24
# max_features 3
# Training Accuracy %: 0.6845000528646494
# Testing Accuracy %: 0.36417322668757535
# nodes 15
# n_estimators 24
# max_features 4
# Training Accuracy %: 0.699422917843576
# Testing Accuracy %: 0.41074275758624024
# nodes 15
# n_estimators 24
# max_features 5
# Training Accuracy %: 0.7184336819789015
# Testing Accuracy %: 0.45680047874003604
# nodes 15
# n_estimators 24
# max_features 6
# Training Accuracy %: 0.7084614981546256
# Testing Accuracy %: 0.44552966962863727
# nodes 15
# n_estimators 24
# max_features 7
# Training Accuracy %: 0.7161056143743072
# Testing Accuracy %: 0.45703066550038807
# nodes 15
# n_estimators 24
# max_features 8
# Training Accuracy %: 0.7219163582482588
# Testing Accuracy %: 0.43025513756002887
# nodes 15
# n_estimators 25
# max_features 1
# Training Accuracy %: 0.6077586951369842
# Testing Accuracy %: 0.37699716719943
# nodes 15
# n_estimators 25
# max_features 2
# Training Accuracy %: 0.6720172290272718
# Testing Accuracy %: 0.364308096169344
# nodes 15
# n_estimators 25
# max_features 3
# Training Accuracy %: 0.6857463314261995
# Testing Accuracy %: 0.36980153828299434
# nodes 15
# n_estimators 25
# max_features 4
# Training Accuracy %: 0.6993202707623372
# Testing Accuracy %: 0.40761547559628675
# nodes 15
# n_estimators 25
# max_features 5
# Training Accuracy %: 0.7160618647732062
# Testing Accuracy %: 0.45804085882928236
# nodes 15
# n_estimators 25
# max_features 6
# Training Accuracy %: 0.7080836253458087
# Testing Accuracy %: 0.4441770312860259
# nodes 15
# n_estimators 25
# max_features 7
# Training Accuracy %: 0.7181235517077382
# Testing Accuracy %: 0.46280826520126606
# nodes 15
# n_estimators 25
# max_features 8
# Training Accuracy %: 0.7215493114024346
# Testing Accuracy %: 0.4323517529505997
# nodes 15
# n_estimators 26
# max_features 1
# Training Accuracy %: 0.6013992842859495
# Testing Accuracy %: 0.3750097511839572
# nodes 15
# n_estimators 26
# max_features 2
# Training Accuracy %: 0.6744288701666583
# Testing Accuracy %: 0.3738196837035427
# nodes 15
# n_estimators 26
# max_features 3
# Training Accuracy %: 0.6870578821513209
# Testing Accuracy %: 0.37139718224278273
# nodes 15
# n_estimators 26
# max_features 4
# Training Accuracy %: 0.7017066083957924
# Testing Accuracy %: 0.4063584329797606
# nodes 15
# n_estimators 26
# max_features 5
# Training Accuracy %: 0.7159907267110706
# Testing Accuracy %: 0.45227076653762566
# nodes 15
# n_estimators 26
# max_features 6
# Training Accuracy %: 0.7103223586219567
# Testing Accuracy %: 0.44860313876699864
# nodes 15
# n_estimators 26
# max_features 7
# Training Accuracy %: 0.7189309603774052
# Testing Accuracy %: 0.4623102877355131
# nodes 15
# n_estimators 26
# max_features 8
# Training Accuracy %: 0.7224373179749769
# Testing Accuracy %: 0.4252487887175651
# nodes 15
# n_estimators 27
# max_features 1
# Training Accuracy %: 0.6017811600183651
# Testing Accuracy %: 0.37502647956503876
# nodes 15
# n_estimators 27
# max_features 2
# Training Accuracy %: 0.6777897026372737
# Testing Accuracy %: 0.37651929077084034
# nodes 15
# n_estimators 27
# max_features 3
# Training Accuracy %: 0.6888933243853088
# Testing Accuracy %: 0.3762331942234104
# nodes 15
# n_estimators 27
# max_features 4
# Training Accuracy %: 0.7026204116212942
# Testing Accuracy %: 0.40984314385569875
# nodes 15
# n_estimators 27
# max_features 5
# Training Accuracy %: 0.7160574399578841
# Testing Accuracy %: 0.4483282191274883
# nodes 15
# n_estimators 27
# max_features 6
# Training Accuracy %: 0.7115913762467461
# Testing Accuracy %: 0.4490535768919983
# nodes 15
# n_estimators 27
# max_features 7
# Training Accuracy %: 0.7200206994879053
# Testing Accuracy %: 0.45850615659322635
# nodes 15
# n_estimators 27
# max_features 8
# Training Accuracy %: 0.7235086048049104
# Testing Accuracy %: 0.429811820522904
# nodes 15
# n_estimators 28
# max_features 1
# Training Accuracy %: 0.6041217931418239
# Testing Accuracy %: 0.38645471051479574
# nodes 15
# n_estimators 28
# max_features 2
# Training Accuracy %: 0.6787945251441174
# Testing Accuracy %: 0.375737737570656
# nodes 15
# n_estimators 28
# max_features 3
# Training Accuracy %: 0.6888295501960933
# Testing Accuracy %: 0.365215163201982
# nodes 15
# n_estimators 28
# max_features 4
# Training Accuracy %: 0.7029148313098654
# Testing Accuracy %: 0.4074445481419572
# nodes 15
# n_estimators 28
# max_features 5
# Training Accuracy %: 0.7145097494216962
# Testing Accuracy %: 0.44252837659833066
# nodes 15
# n_estimators 28
# max_features 6
# Training Accuracy %: 0.7111869427853056
# Testing Accuracy %: 0.44950080593796715
# nodes 15
# n_estimators 28
# max_features 7
# Training Accuracy %: 0.7194964647948515
# Testing Accuracy %: 0.45799792911744
# nodes 15
# n_estimators 28
# max_features 8
# Training Accuracy %: 0.7229934451508602
# Testing Accuracy %: 0.43089591245063574
# nodes 15
# n_estimators 29
# max_features 1
# Training Accuracy %: 0.6050619655865301
# Testing Accuracy %: 0.3867609349453498
# nodes 15
# n_estimators 29
# max_features 2
# Training Accuracy %: 0.6806713203331058
# Testing Accuracy %: 0.3866127755998139
# nodes 15
# n_estimators 29
# max_features 3
# Training Accuracy %: 0.6898737046244743
# Testing Accuracy %: 0.3693275677052742
# nodes 15
# n_estimators 29
# max_features 4
# Training Accuracy %: 0.7056308466345473
# Testing Accuracy %: 0.40898770413230257
# nodes 15
# n_estimators 29
# max_features 5
# Training Accuracy %: 0.7153886018925948
# Testing Accuracy %: 0.4456249986906732
# nodes 15
# n_estimators 29
# max_features 6
# Training Accuracy %: 0.7129800098200872
# Testing Accuracy %: 0.458161966112828
# nodes 15
# n_estimators 29
# max_features 7
# Training Accuracy %: 0.719495005263565
# Testing Accuracy %: 0.4606393510620693
# nodes 15
# n_estimators 29
# max_features 8
# Training Accuracy %: 0.722504025662035
# Testing Accuracy %: 0.4330921866592199
# nodes 15
# n_estimators 30
# max_features 1
# Training Accuracy %: 0.6082596410838907
# Testing Accuracy %: 0.3933929580365565
# nodes 15
# n_estimators 30
# max_features 2
# Training Accuracy %: 0.6777301383043768
# Testing Accuracy %: 0.3824851315844858
# nodes 15
# n_estimators 30
# max_features 3
# Training Accuracy %: 0.6905369900870699
# Testing Accuracy %: 0.3667299237767324
# nodes 15
# n_estimators 30
# max_features 4
# Training Accuracy %: 0.7056620347499429
# Testing Accuracy %: 0.41122324592810744
# nodes 15
# n_estimators 30
# max_features 5
# Training Accuracy %: 0.7150063992731891
# Testing Accuracy %: 0.44784370860901945
# nodes 15
# n_estimators 30
# max_features 6
# Training Accuracy %: 0.7126264239024479
# Testing Accuracy %: 0.45551069104399156
# nodes 15
# n_estimators 30
# max_features 7
# Training Accuracy %: 0.7191361755797651
# Testing Accuracy %: 0.45005166888529735
# nodes 15
# n_estimators 30
# max_features 8
# Training Accuracy %: 0.7218026662306251
# Testing Accuracy %: 0.42410046573325666
# nodes 15
# n_estimators 31
# max_features 1
# Training Accuracy %: 0.6074476508091414
# Testing Accuracy %: 0.3946156600390738
# nodes 15
# n_estimators 31
# max_features 2
# Training Accuracy %: 0.679076352594234
# Testing Accuracy %: 0.37546839104493335
# nodes 15
# n_estimators 31
# max_features 3
# Training Accuracy %: 0.6889614637603236
# Testing Accuracy %: 0.37092788936014565
# nodes 15
# n_estimators 31
# max_features 4
# Training Accuracy %: 0.706812584656642
# Testing Accuracy %: 0.4164901250770824
# nodes 15
# n_estimators 31
# max_features 5
# Training Accuracy %: 0.7148424101438828
# Testing Accuracy %: 0.4478464318519755
# nodes 15
# n_estimators 31
# max_features 6
# Training Accuracy %: 0.7118618585319532
# Testing Accuracy %: 0.4521121775452399
# nodes 15
# n_estimators 31
# max_features 7
# Training Accuracy %: 0.7181694087764519
# Testing Accuracy %: 0.4453523937345254
# nodes 15
# n_estimators 31
# max_features 8
# Training Accuracy %: 0.7201887349731845
# Testing Accuracy %: 0.41896315080624935
# nodes 15
# n_estimators 32
# max_features 1
# Training Accuracy %: 0.606694860220056
# Testing Accuracy %: 0.3924526717728011
# nodes 15
# n_estimators 32
# max_features 2
# Training Accuracy %: 0.6792606854366794
# Testing Accuracy %: 0.3734458204038261
# nodes 15
# n_estimators 32
# max_features 3
# Training Accuracy %: 0.690441852661517
# Testing Accuracy %: 0.36905084469547755
# nodes 15
# n_estimators 32
# max_features 4
# Training Accuracy %: 0.7075217618095652
# Testing Accuracy %: 0.42112056366782513
# nodes 15
# n_estimators 32
# max_features 5
# Training Accuracy %: 0.7141483754479243
# Testing Accuracy %: 0.444997365512352
# nodes 15
# n_estimators 32
# max_features 6
# Training Accuracy %: 0.7113976818350101
# Testing Accuracy %: 0.45032257188323166
# nodes 15
# n_estimators 32
# max_features 7
# Training Accuracy %: 0.7191749396450581
# Testing Accuracy %: 0.44559784048411144
# nodes 15
# n_estimators 32
# max_features 8
# Training Accuracy %: 0.7213078537452939
# Testing Accuracy %: 0.4180421442156931
# nodes 15
# n_estimators 33
# max_features 1
# Training Accuracy %: 0.6066687366473777
# Testing Accuracy %: 0.39297292632813585
# nodes 15
# n_estimators 33
# max_features 2
# Training Accuracy %: 0.6806598030905711
# Testing Accuracy %: 0.3813525077119132
# nodes 15
# n_estimators 33
# max_features 3
# Training Accuracy %: 0.6917679811744808
# Testing Accuracy %: 0.3752647168322696
# nodes 15
# n_estimators 33
# max_features 4
# Training Accuracy %: 0.7075808474186344
# Testing Accuracy %: 0.42898609519191544
# nodes 15
# n_estimators 33
# max_features 5
# Training Accuracy %: 0.7155476148041138
# Testing Accuracy %: 0.452240104463997
# nodes 15
# n_estimators 33
# max_features 6
# Training Accuracy %: 0.7109399507720953
# Testing Accuracy %: 0.45133649570864287
# nodes 15
# n_estimators 33
# max_features 7
# Training Accuracy %: 0.7185880957393442
# Testing Accuracy %: 0.44829679580952664
# nodes 15
# n_estimators 33
# max_features 8
# Training Accuracy %: 0.7207463827536802
# Testing Accuracy %: 0.41836066786376214
# nodes 15
# n_estimators 34
# max_features 1
# Training Accuracy %: 0.60704141598632
# Testing Accuracy %: 0.4004016529624119
# nodes 15
# n_estimators 34
# max_features 2
# Training Accuracy %: 0.6793162930200083
# Testing Accuracy %: 0.38584208578554324
# nodes 15
# n_estimators 34
# max_features 3
# Training Accuracy %: 0.6920395227648131
# Testing Accuracy %: 0.3840180917592889
# nodes 15
# n_estimators 34
# max_features 4
# Training Accuracy %: 0.70804696330215
# Testing Accuracy %: 0.43475022026850096
# nodes 15
# n_estimators 34
# max_features 5
# Training Accuracy %: 0.7155656488825917
# Testing Accuracy %: 0.4509076250206605
# nodes 15
# n_estimators 34
# max_features 6
# Training Accuracy %: 0.7117817724489763
# Testing Accuracy %: 0.44889021707305576
# nodes 15
# n_estimators 34
# max_features 7
# Training Accuracy %: 0.7182546874894629
# Testing Accuracy %: 0.44653576801376504
# nodes 15
# n_estimators 34
# max_features 8
# Training Accuracy %: 0.7210381771103339
# Testing Accuracy %: 0.4188332090726935
# nodes 15
# n_estimators 35
# max_features 1
# Training Accuracy %: 0.6078782380393408
# Testing Accuracy %: 0.4005290054144873
# nodes 15
# n_estimators 35
# max_features 2
# Training Accuracy %: 0.6792229804367973
# Testing Accuracy %: 0.38366517300156555
# nodes 15
# n_estimators 35
# max_features 3
# Training Accuracy %: 0.6936163806658227
# Testing Accuracy %: 0.38393338743966043
# nodes 15
# n_estimators 35
# max_features 4
# Training Accuracy %: 0.7074798415828153
# Testing Accuracy %: 0.42948461351944833
# nodes 15
# n_estimators 35
# max_features 5
# Training Accuracy %: 0.71554194753448
# Testing Accuracy %: 0.4477112645819138
# nodes 15
# n_estimators 35
# max_features 6
# Training Accuracy %: 0.7121413824555642
# Testing Accuracy %: 0.4409503313844607
# nodes 15
# n_estimators 35
# max_features 7
# Training Accuracy %: 0.7183355460891292
# Testing Accuracy %: 0.4384759446297637
# nodes 15
# n_estimators 35
# max_features 8
# Training Accuracy %: 0.7210638430884321
# Testing Accuracy %: 0.4115325379606557
# nodes 15
# n_estimators 36
# max_features 1
# Training Accuracy %: 0.6100649167907544
# Testing Accuracy %: 0.40074348071676325
# nodes 15
# n_estimators 36
# max_features 2
# Training Accuracy %: 0.6771926369556265
# Testing Accuracy %: 0.3797244307390668
# nodes 15
# n_estimators 36
# max_features 3
# Training Accuracy %: 0.693778705142013
# Testing Accuracy %: 0.3835683237135067
# nodes 15
# n_estimators 36
# max_features 4
# Training Accuracy %: 0.7074180472478417
# Testing Accuracy %: 0.4276388009087232
# nodes 15
# n_estimators 36
# max_features 5
# Training Accuracy %: 0.7158864498169288
# Testing Accuracy %: 0.44545215316873044
# nodes 15
# n_estimators 36
# max_features 6
# Training Accuracy %: 0.7116269986396312
# Testing Accuracy %: 0.43514647094889447
# nodes 15
# n_estimators 36
# max_features 7
# Training Accuracy %: 0.7176713117095213
# Testing Accuracy %: 0.43403124292187745
# nodes 15
# n_estimators 36
# max_features 8
# Training Accuracy %: 0.7213475615619611
# Testing Accuracy %: 0.40897932566730755
# nodes 15
# n_estimators 37
# max_features 1
# Training Accuracy %: 0.6110550373339576
# Testing Accuracy %: 0.4043015825965185
# nodes 15
# n_estimators 37
# max_features 2
# Training Accuracy %: 0.6774924975991643
# Testing Accuracy %: 0.38351041526436513
# nodes 15
# n_estimators 37
# max_features 3
# Training Accuracy %: 0.6942267465967806
# Testing Accuracy %: 0.38734009227672306
# nodes 15
# n_estimators 37
# max_features 4
# Training Accuracy %: 0.707713107033673
# Testing Accuracy %: 0.4323215280376229
# nodes 15
# n_estimators 37
# max_features 5
# Training Accuracy %: 0.7179309439273782
# Testing Accuracy %: 0.44989203367060826
# nodes 15
# n_estimators 37
# max_features 6
# Training Accuracy %: 0.7109577206165786
# Testing Accuracy %: 0.4330123677134311
# nodes 15
# n_estimators 37
# max_features 7
# Training Accuracy %: 0.7167948780092555
# Testing Accuracy %: 0.43093953822769815
# nodes 15
# n_estimators 37
# max_features 8
# Training Accuracy %: 0.7209368477136374
# Testing Accuracy %: 0.40662501533280415
# nodes 15
# n_estimators 38
# max_features 1
# Training Accuracy %: 0.6113220127068255
# Testing Accuracy %: 0.40428045496561027
# nodes 15
# n_estimators 38
# max_features 2
# Training Accuracy %: 0.6785112844177313
# Testing Accuracy %: 0.3891499284855119
# nodes 15
# n_estimators 38
# max_features 3
# Training Accuracy %: 0.6957266267330136
# Testing Accuracy %: 0.3953238828267771
# nodes 15
# n_estimators 38
# max_features 4
# Training Accuracy %: 0.7087340179417139
# Testing Accuracy %: 0.43042650864013166
# nodes 15
# n_estimators 38
# max_features 5
# Training Accuracy %: 0.718702275351776
# Testing Accuracy %: 0.4506182994624832
# nodes 15
# n_estimators 38
# max_features 6
# Training Accuracy %: 0.7119054010210767
# Testing Accuracy %: 0.43644397492136344
# nodes 15
# n_estimators 38
# max_features 7
# Training Accuracy %: 0.7169922053682592
# Testing Accuracy %: 0.42980350423449787
# nodes 15
# n_estimators 38
# max_features 8
# Training Accuracy %: 0.721257890098904
# Testing Accuracy %: 0.40068233168844336
# nodes 15
# n_estimators 39
# max_features 1
# Training Accuracy %: 0.6106188354296376
# Testing Accuracy %: 0.40296147186912257
# nodes 15
# n_estimators 39
# max_features 2
# Training Accuracy %: 0.6810680117829451
# Testing Accuracy %: 0.3890512384944206
# nodes 15
# n_estimators 39
# max_features 3
# Training Accuracy %: 0.6952725277331901
# Testing Accuracy %: 0.39575632108668
# nodes 15
# n_estimators 39
# max_features 4
# Training Accuracy %: 0.7082124411243074
# Testing Accuracy %: 0.4284541448283693
# nodes 15
# n_estimators 39
# max_features 5
# Training Accuracy %: 0.7193260909392485
# Testing Accuracy %: 0.4504748226911772
# nodes 15
# n_estimators 39
# max_features 6
# Training Accuracy %: 0.712918356194527
# Testing Accuracy %: 0.4372689147725608
# nodes 15
# n_estimators 39
# max_features 7
# Training Accuracy %: 0.7163440591760568
# Testing Accuracy %: 0.43115292446771136
# nodes 15
# n_estimators 39
# max_features 8
# Training Accuracy %: 0.7210063342875757
# Testing Accuracy %: 0.4023777679185685
# nodes 15
# n_estimators 40
# max_features 1
# Training Accuracy %: 0.6114201621285753
# Testing Accuracy %: 0.4027136258167525
# nodes 15
# n_estimators 40
# max_features 2
# Training Accuracy %: 0.6790501458261251
# Testing Accuracy %: 0.3887375451111582
# nodes 15
# n_estimators 40
# max_features 3
# Training Accuracy %: 0.6953682208196343
# Testing Accuracy %: 0.39991141107842887
# nodes 15
# n_estimators 40
# max_features 4
# Training Accuracy %: 0.7066184781036999
# Testing Accuracy %: 0.4338148671466856
# nodes 15
# n_estimators 40
# max_features 5
# Training Accuracy %: 0.7195995030557459
# Testing Accuracy %: 0.44783718220699575
# nodes 15
# n_estimators 40
# max_features 6
# Training Accuracy %: 0.7149287322880855
# Testing Accuracy %: 0.44173667771664715
# nodes 15
# n_estimators 40
# max_features 7
# Training Accuracy %: 0.717628212499606
# Testing Accuracy %: 0.43512200375756305
# nodes 15
# n_estimators 40
# max_features 8
# Training Accuracy %: 0.7218893856648767
# Testing Accuracy %: 0.4070064985294206
# nodes 15
# n_estimators 41
# max_features 1
# Training Accuracy %: 0.6106707066233192
# Testing Accuracy %: 0.39885829271419304
# nodes 15
# n_estimators 41
# max_features 2
# Training Accuracy %: 0.6802323232555005
# Testing Accuracy %: 0.39104290113345874
# nodes 15
# n_estimators 41
# max_features 3
# Training Accuracy %: 0.6948766759972764
# Testing Accuracy %: 0.3970805219400755
# nodes 15
# n_estimators 41
# max_features 4
# Training Accuracy %: 0.7069367655317738
# Testing Accuracy %: 0.4265585318409044
# nodes 15
# n_estimators 41
# max_features 5
# Training Accuracy %: 0.7194902338329279
# Testing Accuracy %: 0.4449055269962159
# nodes 15
# n_estimators 41
# max_features 6
# Training Accuracy %: 0.7152266083011738
# Testing Accuracy %: 0.4419423301881127
# nodes 15
# n_estimators 41
# max_features 7
# Training Accuracy %: 0.7178406432454592
# Testing Accuracy %: 0.43238235955438264
# nodes 15
# n_estimators 41
# max_features 8
# Training Accuracy %: 0.7221233811602799
# Testing Accuracy %: 0.40461802406611314
# nodes 15
# n_estimators 42
# max_features 1
# Training Accuracy %: 0.6092872999449964
# Testing Accuracy %: 0.39450085123264544
# nodes 15
# n_estimators 42
# max_features 2
# Training Accuracy %: 0.6794883507000752
# Testing Accuracy %: 0.39215475555301105
# nodes 15
# n_estimators 42
# max_features 3
# Training Accuracy %: 0.6947209512168833
# Testing Accuracy %: 0.39337449854851636
# nodes 15
# n_estimators 42
# max_features 4
# Training Accuracy %: 0.7067565090216323
# Testing Accuracy %: 0.4204511463185632
# nodes 15
# n_estimators 42
# max_features 5
# Training Accuracy %: 0.7190498803913776
# Testing Accuracy %: 0.4402831489560767
# nodes 15
# n_estimators 42
# max_features 6
# Training Accuracy %: 0.7146236124232108
# Testing Accuracy %: 0.4392721458618366
# nodes 15
# n_estimators 42
# max_features 7
# Training Accuracy %: 0.7174248056380932
# Testing Accuracy %: 0.42914621006426434
# nodes 15
# n_estimators 42
# max_features 8
# Training Accuracy %: 0.72186190732874
# Testing Accuracy %: 0.40218883424161944
# nodes 15
# n_estimators 43
# max_features 1
# Training Accuracy %: 0.6107958228211443
# Testing Accuracy %: 0.3986868905209463
# nodes 15
# n_estimators 43
# max_features 2
# Training Accuracy %: 0.6790484110119044
# Testing Accuracy %: 0.3965419229904543
# nodes 15
# n_estimators 43
# max_features 3
# Training Accuracy %: 0.6944854002402108
# Testing Accuracy %: 0.3965809521718031
# nodes 15
# n_estimators 43
# max_features 4
# Training Accuracy %: 0.704622738455598
# Testing Accuracy %: 0.42781485116846985
# nodes 15
# n_estimators 43
# max_features 5
# Training Accuracy %: 0.7192262378060288
# Testing Accuracy %: 0.44505920028125057
# nodes 15
# n_estimators 43
# max_features 6
# Training Accuracy %: 0.7144882283525823
# Testing Accuracy %: 0.43771588416668616
# nodes 15
# n_estimators 43
# max_features 7
# Training Accuracy %: 0.7171406393648534
# Testing Accuracy %: 0.43479282105200734
# nodes 15
# n_estimators 43
# max_features 8
# Training Accuracy %: 0.7222878868486323
# Testing Accuracy %: 0.4065674294787698
# nodes 15
# n_estimators 44
# max_features 1
# Training Accuracy %: 0.6101414637706639
# Testing Accuracy %: 0.3979499582291749
# nodes 15
# n_estimators 44
# max_features 2
# Training Accuracy %: 0.678691918261871
# Testing Accuracy %: 0.3946588733719021
# nodes 15
# n_estimators 44
# max_features 3
# Training Accuracy %: 0.6944141877399332
# Testing Accuracy %: 0.39932586270012804
# nodes 15
# n_estimators 44
# max_features 4
# Training Accuracy %: 0.7052340719992336
# Testing Accuracy %: 0.4311255517785607
# nodes 15
# n_estimators 44
# max_features 5
# Training Accuracy %: 0.7190333803347997
# Testing Accuracy %: 0.4473720047633333
# nodes 15
# n_estimators 44
# max_features 6
# Training Accuracy %: 0.714651479189433
# Testing Accuracy %: 0.43861829837971666
# nodes 15
# n_estimators 44
# max_features 7
# Training Accuracy %: 0.7172838227794187
# Testing Accuracy %: 0.437713871565655
# nodes 15
# n_estimators 44
# max_features 8
# Training Accuracy %: 0.7223768685251206
# Testing Accuracy %: 0.41154386936331444
# nodes 15
# n_estimators 45
# max_features 1
# Training Accuracy %: 0.6099358681748835
# Testing Accuracy %: 0.3933404900762325
# nodes 15
# n_estimators 45
# max_features 2
# Training Accuracy %: 0.6781190809796364
# Testing Accuracy %: 0.39560055716650777
# nodes 15
# n_estimators 45
# max_features 3
# Training Accuracy %: 0.6935826051202072
# Testing Accuracy %: 0.39661035543295753
# nodes 15
# n_estimators 45
# max_features 4
# Training Accuracy %: 0.7045530666688128
# Testing Accuracy %: 0.4262316482424158
# nodes 15
# n_estimators 45
# max_features 5
# Training Accuracy %: 0.7190267253599962
# Testing Accuracy %: 0.4469328038541506
# nodes 15
# n_estimators 45
# max_features 6
# Training Accuracy %: 0.71502206500154
# Testing Accuracy %: 0.43817536540884416
# nodes 15
# n_estimators 45
# max_features 7
# Training Accuracy %: 0.7174869992200452
# Testing Accuracy %: 0.43923295660250594
# nodes 15
# n_estimators 45
# max_features 8
# Training Accuracy %: 0.7228421951908345
# Testing Accuracy %: 0.41495105465057824
# nodes 15
# n_estimators 46
# max_features 1
# Training Accuracy %: 0.6095538676174033
# Testing Accuracy %: 0.39620480125235147
# nodes 15
# n_estimators 46
# max_features 2
# Training Accuracy %: 0.6784586871062819
# Testing Accuracy %: 0.39338457946021543
# nodes 15
# n_estimators 46
# max_features 3
# Training Accuracy %: 0.6934318468330142
# Testing Accuracy %: 0.4021591107714344
# nodes 15
# n_estimators 46
# max_features 4
# Training Accuracy %: 0.7059891654225685
# Testing Accuracy %: 0.43184213561336227
# nodes 15
# n_estimators 46
# max_features 5
# Training Accuracy %: 0.7196744899324472
# Testing Accuracy %: 0.4502942873805087
# nodes 15
# n_estimators 46
# max_features 6
# Training Accuracy %: 0.7161033235169147
# Testing Accuracy %: 0.4431044974391969
# nodes 15
# n_estimators 46
# max_features 7
# Training Accuracy %: 0.7177724223181647
# Testing Accuracy %: 0.4433117782285724
# nodes 15
# n_estimators 46
# max_features 8
# Training Accuracy %: 0.7246348248799483
# Testing Accuracy %: 0.42002790231343834
# nodes 15
# n_estimators 47
# max_features 1
# Training Accuracy %: 0.6099260784918079
# Testing Accuracy %: 0.39545071047550684
# nodes 15
# n_estimators 47
# max_features 2
# Training Accuracy %: 0.6780296774680101
# Testing Accuracy %: 0.3912533785474944
# nodes 15
# n_estimators 47
# max_features 3
# Training Accuracy %: 0.6946567376975411
# Testing Accuracy %: 0.40648863590259166
# nodes 15
# n_estimators 47
# max_features 4
# Training Accuracy %: 0.7079069233142798
# Testing Accuracy %: 0.4368303492757395
# nodes 15
# n_estimators 47
# max_features 5
# Training Accuracy %: 0.7197449747681683
# Testing Accuracy %: 0.4502439000556262
# nodes 15
# n_estimators 47
# max_features 6
# Training Accuracy %: 0.7168871388386024
# Testing Accuracy %: 0.4469309983425668
# nodes 15
# n_estimators 47
# max_features 7
# Training Accuracy %: 0.7179417022723442
# Testing Accuracy %: 0.4410515162597295
# nodes 15
# n_estimators 47
# max_features 8
# Training Accuracy %: 0.7250552404837466
# Testing Accuracy %: 0.42389580427103746
# nodes 15
# n_estimators 48
# max_features 1
# Training Accuracy %: 0.6106376996577431
# Testing Accuracy %: 0.3936513216471126
# nodes 15
# n_estimators 48
# max_features 2
# Training Accuracy %: 0.6779149768325907
# Testing Accuracy %: 0.39166358507416654
# nodes 15
# n_estimators 48
# max_features 3
# Training Accuracy %: 0.6948227888623395
# Testing Accuracy %: 0.40619460878699176
# nodes 15
# n_estimators 48
# max_features 4
# Training Accuracy %: 0.7087341788469104
# Testing Accuracy %: 0.4391613729744154
# nodes 15
# n_estimators 48
# max_features 5
# Training Accuracy %: 0.719570876035847
# Testing Accuracy %: 0.4477718734731221
# nodes 15
# n_estimators 48
# max_features 6
# Training Accuracy %: 0.7173553033165858
# Testing Accuracy %: 0.4427634729442822
# nodes 15
# n_estimators 48
# max_features 7
# Training Accuracy %: 0.7184183687104374
# Testing Accuracy %: 0.4370670710805661
# nodes 15
# n_estimators 48
# max_features 8
# Training Accuracy %: 0.7251075118146104
# Testing Accuracy %: 0.4185854952978938
# nodes 15
# n_estimators 49
# max_features 1
# Training Accuracy %: 0.610178195185258
# Testing Accuracy %: 0.3924626004216627
# nodes 15
# n_estimators 49
# max_features 2
# Training Accuracy %: 0.6779884521081618
# Testing Accuracy %: 0.3916831732597803
# nodes 15
# n_estimators 49
# max_features 3
# Training Accuracy %: 0.6937919270859083
# Testing Accuracy %: 0.40615882118185775
# nodes 15
# n_estimators 49
# max_features 4
# Training Accuracy %: 0.7083852885788766
# Testing Accuracy %: 0.43715807225172065
# nodes 15
# n_estimators 49
# max_features 5
# Training Accuracy %: 0.7199236545610654
# Testing Accuracy %: 0.45001105402230657
# nodes 15
# n_estimators 49
# max_features 6
# Training Accuracy %: 0.7173265908968208
# Testing Accuracy %: 0.4431852452454934
# nodes 15
# n_estimators 49
# max_features 7
# Training Accuracy %: 0.718418946227988
# Testing Accuracy %: 0.4389116989196019
# nodes 15
# n_estimators 49
# max_features 8
# Training Accuracy %: 0.7255009639513179
# Testing Accuracy %: 0.4184751724454979
# nodes 15
# n_estimators 50
# max_features 1
# Training Accuracy %: 0.6079732694115929
# Testing Accuracy %: 0.3928743958003965
# nodes 15
# n_estimators 50
# max_features 2
# Training Accuracy %: 0.6779698694908736
# Testing Accuracy %: 0.39455116055003236
# nodes 15
# n_estimators 50
# max_features 3
# Training Accuracy %: 0.6940336286650364
# Testing Accuracy %: 0.40385586609940627
# nodes 15
# n_estimators 50
# max_features 4
# Training Accuracy %: 0.708893538933877
# Testing Accuracy %: 0.43742486353310683
# nodes 15
# n_estimators 50
# max_features 5
# Training Accuracy %: 0.7199953448697934
# Testing Accuracy %: 0.4510670828531014
# nodes 15
# n_estimators 50
# max_features 6
# Training Accuracy %: 0.7167005371749361
# Testing Accuracy %: 0.44138211553930695
# nodes 15
# n_estimators 50
# max_features 7
# Training Accuracy %: 0.7184927850341175
# Testing Accuracy %: 0.44028281956812887
# nodes 15
# n_estimators 50
# max_features 8
# Training Accuracy %: 0.7259582861479961
# Testing Accuracy %: 0.4191179931881107
# nodes 15
# n_estimators 51
# max_features 1
# Training Accuracy %: 0.6073082942648825
# Testing Accuracy %: 0.3897734789702594
# nodes 15
# n_estimators 51
# max_features 2
# Training Accuracy %: 0.6792420663461363
# Testing Accuracy %: 0.3997197878589047
# nodes 15
# n_estimators 51
# max_features 3
# Training Accuracy %: 0.6948367702325997
# Testing Accuracy %: 0.40441353808055913
# nodes 15
# n_estimators 51
# max_features 4
# Training Accuracy %: 0.7091949373447253
# Testing Accuracy %: 0.44005771409550354
# nodes 15
# n_estimators 51
# max_features 5
# Training Accuracy %: 0.7203831137984391
# Testing Accuracy %: 0.45277438634624445
# nodes 15
# n_estimators 51
# max_features 6
# Training Accuracy %: 0.716950608583785
# Testing Accuracy %: 0.44268251622484334
# nodes 15
# n_estimators 51
# max_features 7
# Training Accuracy %: 0.7188755668300362
# Testing Accuracy %: 0.440858159823426
# nodes 15
# n_estimators 51
# max_features 8
# Training Accuracy %: 0.7262450212651692
# Testing Accuracy %: 0.4205142834174146
# nodes 15
# n_estimators 52
# max_features 1
# Training Accuracy %: 0.6067006748050436
# Testing Accuracy %: 0.3920487246794041
# nodes 15
# n_estimators 52
# max_features 2
# Training Accuracy %: 0.6778250000737096
# Testing Accuracy %: 0.4006370839198141
# nodes 15
# n_estimators 52
# max_features 3
# Training Accuracy %: 0.6949707470519588
# Testing Accuracy %: 0.4085570127598972
# nodes 15
# n_estimators 52
# max_features 4
# Training Accuracy %: 0.7095880552204177
# Testing Accuracy %: 0.4392346877704739
# nodes 15
# n_estimators 52
# max_features 5
# Training Accuracy %: 0.7199137829614007
# Testing Accuracy %: 0.4548685874475159
# nodes 15
# n_estimators 52
# max_features 6
# Training Accuracy %: 0.7169472579287777
# Testing Accuracy %: 0.44435872942232535
# nodes 15
# n_estimators 52
# max_features 7
# Training Accuracy %: 0.7198966045116606
# Testing Accuracy %: 0.4409955115223927
# nodes 15
# n_estimators 52
# max_features 8
# Training Accuracy %: 0.7270993260084309
# Testing Accuracy %: 0.42088656095305765
# nodes 15
# n_estimators 53
# max_features 1
# Training Accuracy %: 0.6070996814574805
# Testing Accuracy %: 0.39041827632319626
# nodes 15
# n_estimators 53
# max_features 2
# Training Accuracy %: 0.677616282662977
# Testing Accuracy %: 0.3958781989364174
# nodes 15
# n_estimators 53
# max_features 3
# Training Accuracy %: 0.6947823687210753
# Testing Accuracy %: 0.403248262847123
# nodes 15
# n_estimators 53
# max_features 4
# Training Accuracy %: 0.7089311078310265
# Testing Accuracy %: 0.43559739688348365
# nodes 15
# n_estimators 53
# max_features 5
# Training Accuracy %: 0.720080546386364
# Testing Accuracy %: 0.4512243506050293
# nodes 15
# n_estimators 53
# max_features 6
# Training Accuracy %: 0.7162075028600813
# Testing Accuracy %: 0.44305849376073503
# nodes 15
# n_estimators 53
# max_features 7
# Training Accuracy %: 0.7196929517965207
# Testing Accuracy %: 0.43705437106456924
# nodes 15
# n_estimators 53
# max_features 8
# Training Accuracy %: 0.7268127977383942
# Testing Accuracy %: 0.41773844979429464
# nodes 15
# n_estimators 54
# max_features 1
# Training Accuracy %: 0.6067345084146181
# Testing Accuracy %: 0.39242983375465024
# nodes 15
# n_estimators 54
# max_features 2
# Training Accuracy %: 0.6779429405626471
# Testing Accuracy %: 0.39861899053581906
# nodes 15
# n_estimators 54
# max_features 3
# Training Accuracy %: 0.696729434682374
# Testing Accuracy %: 0.4030274837476664
# nodes 15
# n_estimators 54
# max_features 4
# Training Accuracy %: 0.7104120789719973
# Testing Accuracy %: 0.4373908179313237
# nodes 15
# n_estimators 54
# max_features 5
# Training Accuracy %: 0.7205944676782867
# Testing Accuracy %: 0.4521295543400008
# nodes 15
# n_estimators 54
# max_features 6
# Training Accuracy %: 0.7170428167852347
# Testing Accuracy %: 0.4432430997265
# nodes 15
# n_estimators 54
# max_features 7
# Training Accuracy %: 0.7203800699091011
# Testing Accuracy %: 0.4362588164732978
# nodes 15
# n_estimators 54
# max_features 8
# Training Accuracy %: 0.7274630792424577
# Testing Accuracy %: 0.41781810432292465
# nodes 15
# n_estimators 55
# max_features 1
# Training Accuracy %: 0.606937714479932
# Testing Accuracy %: 0.385910949610488
# nodes 15
# n_estimators 55
# max_features 2
# Training Accuracy %: 0.6776329726532366
# Testing Accuracy %: 0.39591168193807935
# nodes 15
# n_estimators 55
# max_features 3
# Training Accuracy %: 0.6970207862804478
# Testing Accuracy %: 0.4054124245843952
# nodes 15
# n_estimators 55
# max_features 4
# Training Accuracy %: 0.711364068112497
# Testing Accuracy %: 0.44068639467427306
# nodes 15
# n_estimators 55
# max_features 5
# Training Accuracy %: 0.7205932990818249
# Testing Accuracy %: 0.4514441577012034
# nodes 15
# n_estimators 55
# max_features 6
# Training Accuracy %: 0.7173242240119204
# Testing Accuracy %: 0.4418291812878973
# nodes 15
# n_estimators 55
# max_features 7
# Training Accuracy %: 0.7203698811846837
# Testing Accuracy %: 0.4368109011278195
# nodes 15
# n_estimators 55
# max_features 8
# Training Accuracy %: 0.7277174283774466
# Testing Accuracy %: 0.4186792051979109
# nodes 15
# n_estimators 56
# max_features 1
# Training Accuracy %: 0.6088732396402469
# Testing Accuracy %: 0.38671207577800615
# nodes 15
# n_estimators 56
# max_features 2
# Training Accuracy %: 0.6778352920979897
# Testing Accuracy %: 0.39604126129815864
# nodes 15
# n_estimators 56
# max_features 3
# Training Accuracy %: 0.6981834678297727
# Testing Accuracy %: 0.40172171058018624
# nodes 15
# n_estimators 56
# max_features 4
# Training Accuracy %: 0.7120536590569599
# Testing Accuracy %: 0.4414129011325554
# nodes 15
# n_estimators 56
# max_features 5
# Training Accuracy %: 0.7219392095411323
# Testing Accuracy %: 0.45030355170446323
# nodes 15
# n_estimators 56
# max_features 6
# Training Accuracy %: 0.7185860802395293
# Testing Accuracy %: 0.43908568030611006
# nodes 15
# n_estimators 56
# max_features 7
# Training Accuracy %: 0.7219090083851747
# Testing Accuracy %: 0.43738800634542085
# nodes 15
# n_estimators 56
# max_features 8
# Training Accuracy %: 0.7291656397184864
# Testing Accuracy %: 0.4194375789921907
# nodes 15
# n_estimators 57
# max_features 1
# Training Accuracy %: 0.6089103310070578
# Testing Accuracy %: 0.38464598453259424
# nodes 15
# n_estimators 57
# max_features 2
# Training Accuracy %: 0.6777266015707131
# Testing Accuracy %: 0.39416051341739333
# nodes 15
# n_estimators 57
# max_features 3
# Training Accuracy %: 0.6978221720441331
# Testing Accuracy %: 0.398485716373284
# nodes 15
# n_estimators 57
# max_features 4
# Training Accuracy %: 0.712769533787935
# Testing Accuracy %: 0.439087621976077
# nodes 15
# n_estimators 57
# max_features 5
# Training Accuracy %: 0.7217147775622004
# Testing Accuracy %: 0.4503556502915407
# nodes 15
# n_estimators 57
# max_features 6
# Training Accuracy %: 0.7181458774701568
# Testing Accuracy %: 0.440242202811881
# nodes 15
# n_estimators 57
# max_features 7
# Training Accuracy %: 0.7215893001146036
# Testing Accuracy %: 0.4377988586173499
# nodes 15
# n_estimators 57
# max_features 8
# Training Accuracy %: 0.7284817680038563
# Testing Accuracy %: 0.4202189833200839
# nodes 15
# n_estimators 58
# max_features 1
# Training Accuracy %: 0.6073301567684294
# Testing Accuracy %: 0.3844948162633578
# nodes 15
# n_estimators 58
# max_features 2
# Training Accuracy %: 0.6779827793692997
# Testing Accuracy %: 0.3958788761131796
# nodes 15
# n_estimators 58
# max_features 3
# Training Accuracy %: 0.6986295032520977
# Testing Accuracy %: 0.4060118367369848
# nodes 15
# n_estimators 58
# max_features 4
# Training Accuracy %: 0.7129632039063569
# Testing Accuracy %: 0.44025373340055496
# nodes 15
# n_estimators 58
# max_features 5
# Training Accuracy %: 0.7214451117064196
# Testing Accuracy %: 0.4510059367095809
# nodes 15
# n_estimators 58
# max_features 6
# Training Accuracy %: 0.7179303246935677
# Testing Accuracy %: 0.44062833122839806
# nodes 15
# n_estimators 58
# max_features 7
# Training Accuracy %: 0.7219205112354293
# Testing Accuracy %: 0.4395884857641049
# nodes 15
# n_estimators 58
# max_features 8
# Training Accuracy %: 0.7286772830606049
# Testing Accuracy %: 0.4221855674184971
# nodes 15
# n_estimators 59
# max_features 1
# Training Accuracy %: 0.6083504314976068
# Testing Accuracy %: 0.3841550439958237
# nodes 15
# n_estimators 59
# max_features 2
# Training Accuracy %: 0.6775141759130118
# Testing Accuracy %: 0.39653532727690977
# nodes 15
# n_estimators 59
# max_features 3
# Training Accuracy %: 0.6984773166113171
# Testing Accuracy %: 0.40569270542428304
# nodes 15
# n_estimators 59
# max_features 4
# Training Accuracy %: 0.7135504578117974
# Testing Accuracy %: 0.43981628085696034
# nodes 15
# n_estimators 59
# max_features 5
# Training Accuracy %: 0.7207303787017137
# Testing Accuracy %: 0.44902399489699185
# nodes 15
# n_estimators 59
# max_features 6
# Training Accuracy %: 0.7183543580895855
# Testing Accuracy %: 0.4434358218096346
# nodes 15
# n_estimators 59
# max_features 7
# Training Accuracy %: 0.7216293757498864
# Testing Accuracy %: 0.43743300023315634
# nodes 15
# n_estimators 59
# max_features 8
# Training Accuracy %: 0.7290503341539135
# Testing Accuracy %: 0.42430941783814347
# nodes 15
# n_estimators 60
# max_features 1
# Training Accuracy %: 0.6063834417752474
# Testing Accuracy %: 0.3822145411606527
# nodes 15
# n_estimators 60
# max_features 2
# Training Accuracy %: 0.6770591073881597
# Testing Accuracy %: 0.3951143551886309
# nodes 15
# n_estimators 60
# max_features 3
# Training Accuracy %: 0.6995506188365905
# Testing Accuracy %: 0.4060573280460461
# nodes 15
# n_estimators 60
# max_features 4
# Training Accuracy %: 0.7139186282221097
# Testing Accuracy %: 0.4382563293984909
# nodes 15
# n_estimators 60
# max_features 5
# Training Accuracy %: 0.7211043171606227
# Testing Accuracy %: 0.4487646506907086
# nodes 15
# n_estimators 60
# max_features 6
# Training Accuracy %: 0.7189468105891994
# Testing Accuracy %: 0.44164968154030004
# nodes 15
# n_estimators 60
# max_features 7
# Training Accuracy %: 0.7222086583858188
# Testing Accuracy %: 0.43567989446270583
# nodes 15
# n_estimators 60
# max_features 8
# Training Accuracy %: 0.7294647758521855
# Testing Accuracy %: 0.42139036793543694
# nodes 15
# n_estimators 61
# max_features 1
# Training Accuracy %: 0.6074792592419321
# Testing Accuracy %: 0.38230338421180377
# nodes 15
# n_estimators 61
# max_features 2
# Training Accuracy %: 0.6773475667952301
# Testing Accuracy %: 0.4009096712962774
# nodes 15
# n_estimators 61
# max_features 3
# Training Accuracy %: 0.6997026364076144
# Testing Accuracy %: 0.40872159596064706
# nodes 15
# n_estimators 61
# max_features 4
# Training Accuracy %: 0.7139160539670526
# Testing Accuracy %: 0.43880328278538094
# nodes 15
# n_estimators 61
# max_features 5
# Training Accuracy %: 0.720056030512334
# Testing Accuracy %: 0.45076022298536966
# nodes 15
# n_estimators 61
# max_features 6
# Training Accuracy %: 0.719318571755367
# Testing Accuracy %: 0.4452631456326094
# nodes 15
# n_estimators 61
# max_features 7
# Training Accuracy %: 0.7214065163879049
# Testing Accuracy %: 0.43888264288643297
# nodes 15
# n_estimators 61
# max_features 8
# Training Accuracy %: 0.7285679602494416
# Testing Accuracy %: 0.42479231488444236
# nodes 15
# n_estimators 62
# max_features 1
# Training Accuracy %: 0.6099337153039972
# Testing Accuracy %: 0.385178053807684
# nodes 15
# n_estimators 62
# max_features 2
# Training Accuracy %: 0.6769191191331152
# Testing Accuracy %: 0.3979605701499399
# nodes 15
# n_estimators 62
# max_features 3
# Training Accuracy %: 0.6991626140327833
# Testing Accuracy %: 0.4078629425965764
# nodes 15
# n_estimators 62
# max_features 4
# Training Accuracy %: 0.7135977266073914
# Testing Accuracy %: 0.4375751071286902
# nodes 15
# n_estimators 62
# max_features 5
# Training Accuracy %: 0.7207086207190667
# Testing Accuracy %: 0.45056148621408665
# nodes 15
# n_estimators 62
# max_features 6
# Training Accuracy %: 0.719071190097498
# Testing Accuracy %: 0.4444505739500382
# nodes 15
# n_estimators 62
# max_features 7
# Training Accuracy %: 0.7212906902260612
# Testing Accuracy %: 0.43760371222767025
# nodes 15
# n_estimators 62
# max_features 8
# Training Accuracy %: 0.7280740270270016
# Testing Accuracy %: 0.4233798527584718
# nodes 15
# n_estimators 63
# max_features 1
# Training Accuracy %: 0.6109166610055847
# Testing Accuracy %: 0.3835495494840119
# nodes 15
# n_estimators 63
# max_features 2
# Training Accuracy %: 0.6770939893798112
# Testing Accuracy %: 0.39580920011157616
# nodes 15
# n_estimators 63
# max_features 3
# Training Accuracy %: 0.6988084297440245
# Testing Accuracy %: 0.40543801571325155
# nodes 15
# n_estimators 63
# max_features 4
# Training Accuracy %: 0.7137486633744368
# Testing Accuracy %: 0.4384468391474118
# nodes 15
# n_estimators 63
# max_features 5
# Training Accuracy %: 0.7207309752404042
# Testing Accuracy %: 0.4505969387098586
# nodes 15
# n_estimators 63
# max_features 6
# Training Accuracy %: 0.7190261032931302
# Testing Accuracy %: 0.4445146554371564
# nodes 15
# n_estimators 63
# max_features 7
# Training Accuracy %: 0.721312601242204
# Testing Accuracy %: 0.43681510761957787
# nodes 15
# n_estimators 63
# max_features 8
# Training Accuracy %: 0.7278647897456473
# Testing Accuracy %: 0.42307291854571316
# nodes 15
# n_estimators 64
# max_features 1
# Training Accuracy %: 0.6102039671020252
# Testing Accuracy %: 0.3801368308101597
# nodes 15
# n_estimators 64
# max_features 2
# Training Accuracy %: 0.6774827539332886
# Testing Accuracy %: 0.3928044096148441
# nodes 15
# n_estimators 64
# max_features 3
# Training Accuracy %: 0.699666534946437
# Testing Accuracy %: 0.4088153034760851
# nodes 15
# n_estimators 64
# max_features 4
# Training Accuracy %: 0.7142081039454807
# Testing Accuracy %: 0.4405748022868906
# nodes 15
# n_estimators 64
# max_features 5
# Training Accuracy %: 0.7211980443364958
# Testing Accuracy %: 0.450120747292168
# nodes 15
# n_estimators 64
# max_features 6
# Training Accuracy %: 0.7198620447838195
# Testing Accuracy %: 0.44550729695679303
# nodes 15
# n_estimators 64
# max_features 7
# Training Accuracy %: 0.7212185145625283
# Testing Accuracy %: 0.43965083733733734
# nodes 15
# n_estimators 64
# max_features 8
# Training Accuracy %: 0.7284443254024104
# Testing Accuracy %: 0.4244156649238
# nodes 15
# n_estimators 65
# max_features 1
# Training Accuracy %: 0.6114145664756067
# Testing Accuracy %: 0.3820906623296967
# nodes 15
# n_estimators 65
# max_features 2
# Training Accuracy %: 0.6766264976332916
# Testing Accuracy %: 0.39144649180194546
# nodes 15
# n_estimators 65
# max_features 3
# Training Accuracy %: 0.6990117265180201
# Testing Accuracy %: 0.4063945990734693
# nodes 15
# n_estimators 65
# max_features 4
# Training Accuracy %: 0.7131828343199765
# Testing Accuracy %: 0.4392138700318221
# nodes 15
# n_estimators 65
# max_features 5
# Training Accuracy %: 0.7203663056320806
# Testing Accuracy %: 0.4505228322671305
# nodes 15
# n_estimators 65
# max_features 6
# Training Accuracy %: 0.7192014561841238
# Testing Accuracy %: 0.44545252232514265
# nodes 15
# n_estimators 65
# max_features 7
# Training Accuracy %: 0.7216627753968148
# Testing Accuracy %: 0.44126049407946866
# nodes 15
# n_estimators 65
# max_features 8
# Training Accuracy %: 0.7287335254880656
# Testing Accuracy %: 0.42636881805032945
# nodes 15
# n_estimators 66
# max_features 1
# Training Accuracy %: 0.6118775992648027
# Testing Accuracy %: 0.38193183012924614
# nodes 15
# n_estimators 66
# max_features 2
# Training Accuracy %: 0.6762990015736887
# Testing Accuracy %: 0.39504848007860816
# nodes 15
# n_estimators 66
# max_features 3
# Training Accuracy %: 0.6983390552905427
# Testing Accuracy %: 0.4060394665368542
# nodes 15
# n_estimators 66
# max_features 4
# Training Accuracy %: 0.7131937510358297
# Testing Accuracy %: 0.44036272894762996
# nodes 15
# n_estimators 66
# max_features 5
# Training Accuracy %: 0.7208789438743386
# Testing Accuracy %: 0.45238445018889994
# nodes 15
# n_estimators 66
# max_features 6
# Training Accuracy %: 0.7193545768217506
# Testing Accuracy %: 0.44563940188640905
# nodes 15
# n_estimators 66
# max_features 7
# Training Accuracy %: 0.7217908941159017
# Testing Accuracy %: 0.44228911855701025
# nodes 15
# n_estimators 66
# max_features 8
# Training Accuracy %: 0.7286364009875361
# Testing Accuracy %: 0.4268169239577516
# nodes 15
# n_estimators 67
# max_features 1
# Training Accuracy %: 0.6122732119542436
# Testing Accuracy %: 0.3837495478243438
# nodes 15
# n_estimators 67
# max_features 2
# Training Accuracy %: 0.6765380170275659
# Testing Accuracy %: 0.39548292737895396
# nodes 15
# n_estimators 67
# max_features 3
# Training Accuracy %: 0.6982233472746885
# Testing Accuracy %: 0.40431100345798243
# nodes 15
# n_estimators 67
# max_features 4
# Training Accuracy %: 0.7133512859874819
# Testing Accuracy %: 0.4389140170404321
# nodes 15
# n_estimators 67
# max_features 5
# Training Accuracy %: 0.721111237912025
# Testing Accuracy %: 0.4536492310800785
# nodes 15
# n_estimators 67
# max_features 6
# Training Accuracy %: 0.7190548738439948
# Testing Accuracy %: 0.44981252673463756
# nodes 15
# n_estimators 67
# max_features 7
# Training Accuracy %: 0.7221859332597591
# Testing Accuracy %: 0.4436792643997327
# nodes 15
# n_estimators 67
# max_features 8
# Training Accuracy %: 0.7292013260471757
# Testing Accuracy %: 0.4287820627158775
# nodes 15
# n_estimators 68
# max_features 1
# Training Accuracy %: 0.6120779841827315
# Testing Accuracy %: 0.3851211661985168
# nodes 15
# n_estimators 68
# max_features 2
# Training Accuracy %: 0.6763891209205994
# Testing Accuracy %: 0.3994664669123176
# nodes 15
# n_estimators 68
# max_features 3
# Training Accuracy %: 0.6983785191816378
# Testing Accuracy %: 0.4070095938351671
# nodes 15
# n_estimators 68
# max_features 4
# Training Accuracy %: 0.7134495819203766
# Testing Accuracy %: 0.4403467068399157
# nodes 15
# n_estimators 68
# max_features 5
# Training Accuracy %: 0.7207100488629232
# Testing Accuracy %: 0.4550403609909053
# nodes 15
# n_estimators 68
# max_features 6
# Training Accuracy %: 0.7193987926893182
# Testing Accuracy %: 0.4507726384595966
# nodes 15
# n_estimators 68
# max_features 7
# Training Accuracy %: 0.7220245913055354
# Testing Accuracy %: 0.44351695591213836
# nodes 15
# n_estimators 68
# max_features 8
# Training Accuracy %: 0.7294274732662307
# Testing Accuracy %: 0.4293902358696232
# nodes 15
# n_estimators 69
# max_features 1
# Training Accuracy %: 0.6106012655802908
# Testing Accuracy %: 0.3870478929843516
# nodes 15
# n_estimators 69
# max_features 2
# Training Accuracy %: 0.6775173953480034
# Testing Accuracy %: 0.39941231953319467
# nodes 15
# n_estimators 69
# max_features 3
# Training Accuracy %: 0.6983615191138729
# Testing Accuracy %: 0.4058216283337118
# nodes 15
# n_estimators 69
# max_features 4
# Training Accuracy %: 0.71430473536455
# Testing Accuracy %: 0.43813373136756606
# nodes 15
# n_estimators 69
# max_features 5
# Training Accuracy %: 0.7203634554635144
# Testing Accuracy %: 0.45515665764657376
# nodes 15
# n_estimators 69
# max_features 6
# Training Accuracy %: 0.7202545959758563
# Testing Accuracy %: 0.45403223882447863
# nodes 15
# n_estimators 69
# max_features 7
# Training Accuracy %: 0.7229451611540847
# Testing Accuracy %: 0.4443345012712453
# nodes 15
# n_estimators 69
# max_features 8
# Training Accuracy %: 0.7298088604168046
# Testing Accuracy %: 0.42921555197813355
# nodes 15
# n_estimators 70
# max_features 1
# Training Accuracy %: 0.610907761552465
# Testing Accuracy %: 0.3841616725864624
# nodes 15
# n_estimators 70
# max_features 2
# Training Accuracy %: 0.6777859365934524
# Testing Accuracy %: 0.4000910460380016
# nodes 15
# n_estimators 70
# max_features 3
# ...
# Testing Accuracy %: 0.45442229202405193
# nodes 21
# n_estimators 40
# max_features 6
# Training Accuracy %: 0.7685826223050634
# Testing Accuracy %: 0.46292405041029194
# nodes 21
# n_estimators 40
# max_features 7
# Training Accuracy %: 0.7738152556080572
# Testing Accuracy %: 0.44571784764441835
# nodes 21
# n_estimators 40
# max_features 8
# Training Accuracy %: 0.7789145367668013
# Testing Accuracy %: 0.422724428724951
# nodes 21
# n_estimators 41
# max_features 1
# Training Accuracy %: 0.6684813710176832
# Testing Accuracy %: 0.4307367629391591
# nodes 21
# n_estimators 41
# max_features 2
# Training Accuracy %: 0.7383046256409102
# Testing Accuracy %: 0.4013405580034243
# nodes 21
# n_estimators 41
# max_features 3
# Training Accuracy %: 0.7568773575913686
# Testing Accuracy %: 0.39616049555423494
# nodes 21
# n_estimators 41
# max_features 4
# Training Accuracy %: 0.7619894132581045
# Testing Accuracy %: 0.427085636253248
# nodes 21
# n_estimators 41
# max_features 5
# Training Accuracy %: 0.7717033848235053
# Testing Accuracy %: 0.45191134294511204
# nodes 21
# n_estimators 41
# max_features 6
# Training Accuracy %: 0.7688511874562339
# Testing Accuracy %: 0.46313526168490315
# nodes 21
# n_estimators 41
# max_features 7
# Training Accuracy %: 0.7741371596800345
# Testing Accuracy %: 0.44250236612230387
# nodes 21
# n_estimators 41
# max_features 8
# Training Accuracy %: 0.7791084927407357
# Testing Accuracy %: 0.42158777887479637
# nodes 21
# n_estimators 42
# max_features 1
# Training Accuracy %: 0.6669532541819181
# Testing Accuracy %: 0.42683665708856655
# nodes 21
# n_estimators 42
# max_features 2
# Training Accuracy %: 0.7369062027017006
# Testing Accuracy %: 0.4032728094309379
# nodes 21
# n_estimators 42
# max_features 3
# Training Accuracy %: 0.7568819223278549
# Testing Accuracy %: 0.3956399361247833
# nodes 21
# n_estimators 42
# max_features 4
# Training Accuracy %: 0.7615796626043387
# Testing Accuracy %: 0.4225989172217248
# nodes 21
# n_estimators 42
# max_features 5
# Training Accuracy %: 0.7713312314606695
# Testing Accuracy %: 0.44826109998360963
# nodes 21
# n_estimators 42
# max_features 6
# Training Accuracy %: 0.767813251440995
# Testing Accuracy %: 0.46082642453813805
# nodes 21
# n_estimators 42
# max_features 7
# Training Accuracy %: 0.7739776818946875
# Testing Accuracy %: 0.43998471281396867
# nodes 21
# n_estimators 42
# max_features 8
# Training Accuracy %: 0.7793878306769146
# Testing Accuracy %: 0.4201398973173197
# nodes 21
# n_estimators 43
# max_features 1
# Training Accuracy %: 0.6674916322911854
# Testing Accuracy %: 0.4299061262207775
# nodes 21
# n_estimators 43
# max_features 2
# Training Accuracy %: 0.7359866482551607
# Testing Accuracy %: 0.4071078713657781
# nodes 21
# n_estimators 43
# max_features 3
# Training Accuracy %: 0.7567006516582514
# Testing Accuracy %: 0.3970503028804042
# nodes 21
# n_estimators 43
# max_features 4
# Training Accuracy %: 0.7599891765929383
# Testing Accuracy %: 0.4307489437708555
# nodes 21
# n_estimators 43
# max_features 5
# Training Accuracy %: 0.7710780484445927
# Testing Accuracy %: 0.4527040915904199
# nodes 21
# n_estimators 43
# max_features 6
# Training Accuracy %: 0.7676595048982024
# Testing Accuracy %: 0.45742995351848603
# nodes 21
# n_estimators 43
# max_features 7
# Training Accuracy %: 0.7727881117532207
# Testing Accuracy %: 0.4433802307989708
# nodes 21
# n_estimators 43
# max_features 8
# Training Accuracy %: 0.7796513211785256
# Testing Accuracy %: 0.42445922767067545
# nodes 21
# n_estimators 44
# max_features 1
# Training Accuracy %: 0.6668477360660352
# Testing Accuracy %: 0.4291841683848576
# nodes 21
# n_estimators 44
# max_features 2
# Training Accuracy %: 0.7359847991345592
# Testing Accuracy %: 0.4052804789084151
# nodes 21
# n_estimators 44
# max_features 3
# Training Accuracy %: 0.756026702517288
# Testing Accuracy %: 0.39884591256115376
# nodes 21
# n_estimators 44
# max_features 4
# Training Accuracy %: 0.7600755494141337
# Testing Accuracy %: 0.432987859800963
# nodes 21
# n_estimators 44
# max_features 5
# Training Accuracy %: 0.7708762630416022
# Testing Accuracy %: 0.4538403673622985
# nodes 21
# n_estimators 44
# max_features 6
# Training Accuracy %: 0.7681705997226875
# Testing Accuracy %: 0.45762975397595007
# nodes 21
# n_estimators 44
# max_features 7
# Training Accuracy %: 0.7729496583060472
# Testing Accuracy %: 0.44654164620271275
# nodes 21
# n_estimators 44
# max_features 8
# Training Accuracy %: 0.7792261473959762
# Testing Accuracy %: 0.42950214909977424
# nodes 21
# n_estimators 45
# max_features 1
# Training Accuracy %: 0.6663202852445543
# Testing Accuracy %: 0.4263873526230548
# nodes 21
# n_estimators 45
# max_features 2
# Training Accuracy %: 0.7352706657790258
# Testing Accuracy %: 0.40316499755456603
# nodes 21
# n_estimators 45
# max_features 3
# Training Accuracy %: 0.7553584186573147
# Testing Accuracy %: 0.39680152908278554
# nodes 21
# n_estimators 45
# max_features 4
# Training Accuracy %: 0.7594564552211204
# Testing Accuracy %: 0.42814845626002906
# nodes 21
# n_estimators 45
# max_features 5
# Training Accuracy %: 0.7710177432915081
# Testing Accuracy %: 0.45279076399586704
# nodes 21
# n_estimators 45
# max_features 6
# Training Accuracy %: 0.7687254955144152
# Testing Accuracy %: 0.45588341212507777
# nodes 21
# n_estimators 45
# max_features 7
# Training Accuracy %: 0.7730943110581203
# Testing Accuracy %: 0.44768067458388716
# nodes 21
# n_estimators 45
# max_features 8
# Training Accuracy %: 0.7798008448261706
# Testing Accuracy %: 0.4323328219773255
# nodes 21
# n_estimators 46
# max_features 1
# Training Accuracy %: 0.6662756155844646
# Testing Accuracy %: 0.42794926234610264
# nodes 21
# n_estimators 46
# max_features 2
# Training Accuracy %: 0.7359862915019912
# Testing Accuracy %: 0.4004093045622774
# nodes 21
# n_estimators 46
# max_features 3
# Training Accuracy %: 0.7557273470231602
# Testing Accuracy %: 0.4036626204507687
# nodes 21
# n_estimators 46
# max_features 4
# Training Accuracy %: 0.7602407109184935
# Testing Accuracy %: 0.4336210425720265
# nodes 21
# n_estimators 46
# max_features 5
# Training Accuracy %: 0.7721206810612146
# Testing Accuracy %: 0.45367549962948506
# nodes 21
# n_estimators 46
# max_features 6
# Training Accuracy %: 0.7698035356333354
# Testing Accuracy %: 0.4608270144421118
# nodes 21
# n_estimators 46
# max_features 7
# Training Accuracy %: 0.7741643803043571
# Testing Accuracy %: 0.4517391415606614
# nodes 21
# n_estimators 46
# max_features 8
# Training Accuracy %: 0.7813751998528713
# Testing Accuracy %: 0.43503762917434785
# nodes 21
# n_estimators 47
# max_features 1
# Training Accuracy %: 0.6667351968903784
# Testing Accuracy %: 0.4267868028983872
# nodes 21
# n_estimators 47
# max_features 2
# Training Accuracy %: 0.7357018628677439
# Testing Accuracy %: 0.40001997759382235
# nodes 21
# n_estimators 47
# max_features 3
# Training Accuracy %: 0.756262913663436
# Testing Accuracy %: 0.40796942227283717
# nodes 21
# n_estimators 47
# max_features 4
# Training Accuracy %: 0.7619940116827528
# Testing Accuracy %: 0.4383372441167286
# nodes 21
# n_estimators 47
# max_features 5
# Training Accuracy %: 0.7724392055003334
# Testing Accuracy %: 0.4546916637756889
# nodes 21
# n_estimators 47
# max_features 6
# Training Accuracy %: 0.7706138352103372
# Testing Accuracy %: 0.4637540610002078
# nodes 21
# n_estimators 47
# max_features 7
# Training Accuracy %: 0.7741954349049633
# Testing Accuracy %: 0.4508908634308927
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 22
#      20 for max_feature in range (1, 9):
#      21     forest_model = RandomForestRegressor(max_leaf_nodes=nodes,random_state=73073,n_estimators=n_estimator, max_features=max_feature)
# ---> 22     forest_model.fit(X_train,y_train) # train the model with training data
#      24     print('nodes', nodes)
#      25     print('n_estimators', n_estimator)
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:445, in BaseForest.fit(self, X, y, sample_weight)
#     440 if self.warm_start and len(self.estimators_) > 0:
#     441     # We draw from the random state to get the random state we
#     442     # would have got if we hadn't used a warm_start.
#     443     random_state.randint(MAX_INT, size=len(self.estimators_))
# --> 445 trees = [
#     446     self._make_estimator(append=False, random_state=random_state)
#     447     for i in range(n_more_estimators)
#     448 ]
#     450 # Parallel loop: we prefer the threading backend as the Cython code
#     451 # for fitting the trees is internally releasing the Python GIL
#     452 # making threading more efficient than multiprocessing in
#     453 # that case. However, for joblib 0.12+ we respect any
#     454 # parallel_backend contexts set at a higher level,
#     455 # since correctness does not rely on using threads.
#     456 trees = Parallel(
#     457     n_jobs=self.n_jobs,
#     458     verbose=self.verbose,
#    (...)
#     473     for i, t in enumerate(trees)
#     474 )
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:446, in <listcomp>(.0)
#     440 if self.warm_start and len(self.estimators_) > 0:
#     441     # We draw from the random state to get the random state we
#     442     # would have got if we hadn't used a warm_start.
#     443     random_state.randint(MAX_INT, size=len(self.estimators_))
#     445 trees = [
# --> 446     self._make_estimator(append=False, random_state=random_state)
#     447     for i in range(n_more_estimators)
#     448 ]
#     450 # Parallel loop: we prefer the threading backend as the Cython code
#     451 # for fitting the trees is internally releasing the Python GIL
#     452 # making threading more efficient than multiprocessing in
#     453 # that case. However, for joblib 0.12+ we respect any
#     454 # parallel_backend contexts set at a higher level,
#     455 # since correctness does not rely on using threads.
#     456 trees = Parallel(
#     457     n_jobs=self.n_jobs,
#     458     verbose=self.verbose,
#    (...)
#     473     for i, t in enumerate(trees)
#     474 )
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/ensemble/_base.py:187, in BaseEnsemble._make_estimator(self, append, random_state)
#     181 def _make_estimator(self, append=True, random_state=None):
#     182     """Make and configure a copy of the `estimator_` attribute.
#     183
#     184     Warning: This method should be used to properly instantiate new
#     185     sub-estimators.
#     186     """
# --> 187     estimator = clone(self.estimator_)
#     188     estimator.set_params(**{p: getattr(self, p) for p in self.estimator_params})
#     190     if random_state is not None:
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/base.py:75, in clone(estimator, safe)
#      41 """Construct a new unfitted estimator with the same parameters.
#      42
#      43 Clone does a deep copy of the model in an estimator
#    (...)
#      72 found in :ref:`randomness`.
#      73 """
#      74 if hasattr(estimator, "__sklearn_clone__") and not inspect.isclass(estimator):
# ---> 75     return estimator.__sklearn_clone__()
#      76 return _clone_parametrized(estimator, safe=safe)
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/base.py:267, in BaseEstimator.__sklearn_clone__(self)
#     266 def __sklearn_clone__(self):
# --> 267     return _clone_parametrized(self)
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/base.py:105, in _clone_parametrized(estimator, safe)
#      97             raise TypeError(
#      98                 "Cannot clone object '%s' (type %s): "
#      99                 "it does not seem to be a scikit-learn "
#     100                 "estimator as it does not implement a "
#     101                 "'get_params' method." % (repr(estimator), type(estimator))
#     102             )
#     104 klass = estimator.__class__
# --> 105 new_object_params = estimator.get_params(deep=False)
#     106 for name, param in new_object_params.items():
#     107     new_object_params[name] = clone(param, safe=False)
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/base.py:193, in BaseEstimator.get_params(self, deep)
#     178 """
#     179 Get parameters for this estimator.
#     180
#    (...)
#     190     Parameter names mapped to their values.
#     191 """
#     192 out = dict()
# --> 193 for key in self._get_param_names():
#     194     value = getattr(self, key)
#     195     if deep and hasattr(value, "get_params") and not isinstance(value, type):
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/base.py:158, in BaseEstimator._get_param_names(cls)
#     154     return []
#     156 # introspect the constructor arguments to find the model parameters
#     157 # to represent
# --> 158 init_signature = inspect.signature(init)
#     159 # Consider the constructor parameters excluding 'self'
#     160 parameters = [
#     161     p
#     162     for p in init_signature.parameters.values()
#     163     if p.name != "self" and p.kind != p.VAR_KEYWORD
#     164 ]
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/inspect.py:3280, in signature(obj, follow_wrapped, globals, locals, eval_str)
#    3278 def signature(obj, *, follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3279     """Get a signature object for the passed callable."""
# -> 3280     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
#    3281                                    globals=globals, locals=locals, eval_str=eval_str)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/inspect.py:3028, in Signature.from_callable(cls, obj, follow_wrapped, globals, locals, eval_str)
#    3024 @classmethod
#    3025 def from_callable(cls, obj, *,
#    3026                   follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3027     """Constructs Signature for the given callable object."""
# -> 3028     return _signature_from_callable(obj, sigcls=cls,
#    3029                                     follow_wrapper_chains=follow_wrapped,
#    3030                                     globals=globals, locals=locals, eval_str=eval_str)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/inspect.py:2516, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2511             return sig.replace(parameters=new_params)
#    2513 if isfunction(obj) or _signature_is_functionlike(obj):
#    2514     # If it's a pure Python function, or an object that is duck type
#    2515     # of a Python function (Cython functions, for instance), then:
# -> 2516     return _signature_from_function(sigcls, obj,
#    2517                                     skip_bound_arg=skip_bound_arg,
#    2518                                     globals=globals, locals=locals, eval_str=eval_str)
#    2520 if _signature_is_builtin(obj):
#    2521     return _signature_from_builtin(sigcls, obj,
#    2522                                    skip_bound_arg=skip_bound_arg)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/inspect.py:2407, in _signature_from_function(cls, func, skip_bound_arg, globals, locals, eval_str)
#    2404         default = kwdefaults.get(name, _empty)
#    2406     annotation = annotations.get(name, _empty)
# -> 2407     parameters.append(Parameter(name, annotation=annotation,
#    2408                                 kind=_KEYWORD_ONLY,
#    2409                                 default=default))
#    2410 # **kwargs
#    2411 if func_code.co_flags & CO_VARKEYWORDS:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/inspect.py:2688, in Parameter.__init__(self, name, kind, default, annotation)
#    2686 def __init__(self, name, kind, *, default=_empty, annotation=_empty):
#    2687     try:
# -> 2688         self._kind = _ParameterKind(kind)
#    2689     except ValueError:
#    2690         raise ValueError(f'value {kind!r} is not a valid Parameter.kind')
#
# KeyboardInterrupt:

# %%
from sklearn.linear_model import Ridge

lam = .0000001                                                  # hyperparameter
lam_min = 1.0e-10; lam_max = 1.0e10; nlam = 20                           

ridge_model = Ridge(alpha = lam)                             # instantiate the prediction model
ridge_model.fit(X_train,y_train)    

print(ridge_model.score(X_train, y_train))
print(ridge_model.score(X_test, y_test))
# Out:
# 0.3912138897723335
# 0.3529034906055183

# %%
from sklearn.neighbors import KNeighborsRegressor          

k = 45
k_min = 1; k_max=150; nk = 80                         

neigh_model = KNeighborsRegressor(weights = 'uniform', n_neighbors=k, p = 1) # instantiate the prediction model
neigh_model.fit(X_train,y_train)

print(neigh_model.score(X_train, y_train))
print(neigh_model.score(X_test, y_test))
# Out:
# 0.21773658890266312
# 0.1869195733621435
